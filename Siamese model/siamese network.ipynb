# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data.sampler import SubsetRandomSampler
import itertools
import os
import pandas as pd

# Any results you write to the current directory are saved as output.

# %%
print(os.listdir("./pytorch-pretrained-models-for-face-detection/"))
print(os.listdir("./recognizing-faces-in-the-wild/"))
# Out:
# ['VGG Face']
# ['predict', 'predict.csv', 'test', 'train', 'train_relationships.csv']

# %%
#Checking if CUDA is available or not
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Helper Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# # Pre processing relationships Data

# %%
df = pd.read_csv("./recognizing-faces-in-the-wild/train_relationships.csv")
df.head()
# Out:
#            p1          p2
# 0  F0002/MID1  F0002/MID3
# 1  F0002/MID2  F0002/MID3
# 2  F0005/MID1  F0005/MID2
# 3  F0005/MID3  F0005/MID2
# 4  F0009/MID1  F0009/MID4

# %% [markdown]
# We can see the data has two columns of people that are related. Let's split these columns into three i.e. Family, Person1 and Person2

# %%
new = df["p1"].str.split("/", n = 1, expand = True)

# making separate first name column from new data frame 
df["Family1"]= new[0]
# making separate last name column from new data frame 
df["Person1"]= new[1]

# Dropping old Name columns
df.drop(columns =["p1"], inplace = True)

new = df["p2"].str.split("/", n = 1, expand = True)

# making separate first name column from new data frame 
df["Family2"]= new[0]
# making separate last name column from new data frame 
df["Person2"]= new[1]

# Dropping old Name columns
df.drop(columns =["p2"], inplace = True)
df.head()
# Out:
#   Family1 Person1 Family2 Person2
# 0   F0002    MID1   F0002    MID3
# 1   F0002    MID2   F0002    MID3
# 2   F0005    MID1   F0005    MID2
# 3   F0005    MID3   F0005    MID2
# 4   F0009    MID1   F0009    MID4

# %% [markdown]
# It is essential to check if all the folders present in the above DataFrame exist, else it'll be an error while processing the dataset. We should remove the rows that are duplicate and the rows that don't have any folder existing corresponding to their values

# %%
root_dir = './recognizing-faces-in-the-wild/train/'
temp = []
for index, row in df.iterrows():
    if os.path.exists(root_dir+row.Family1+'/'+row.Person1) and os.path.exists(root_dir+row.Family2+'/'+row.Person2):
        continue
    else:
        temp.append(index)
        
print(len(temp))
df = df.drop(temp, axis=0)
# Out:
# 236

# %% [markdown]
# There are 236 rows that don't have any folders corresponding to them so they have been removed

# %% [markdown]
# We can also create some more data from Families for people that are not related. Then we can use this data to train our model on classes 'Related' and 'Not Related'. 'Not Related' instances can be numerous since there are many families that are not correlated. However, that would give a lot of data, We can create new data from people within families that are not related. Eg. A son and daughter would be related to their father and their mother, However, the mother and father won't be related themselves

# %%
#A new column in the existing dataframe with all values as 1, since these people are all related
df['Related'] = 1

#Creating a dictionary, and storing members of each family
df_dict = {}
for index, row in df.iterrows():
    if row['Family1'] in df_dict:
        df_dict[row['Family1']].append(row['Person1'])
    else:
        df_dict[row['Family1']] = [row['Person1']]
        
#For each family in this dictionary, we'll first make pairs of people
#For each pair, we'll check if they're related in our existing Dataset
#If they're not in the dataframe, means we'll create a row with both persons and related value 0
i=1
for key in df_dict:
    pair = list(itertools.combinations(df_dict[key], 2))
    for item in pair:
        if len(df[(df['Family1']==key)&(df['Person1']==item[0])&(df['Person2']==item[1])])==0 \
        and len(df[(df['Family1']==key)&(df['Person1']==item[1])&(df['Person2']==item[0])])==0:
            new = {'Family1':key,'Person1':item[0],'Family2':key,'Person2':item[1],'Related':0}
            df=df.append(new,ignore_index=True)
        
#Storing rows only where Person1 and Person2 are not same
df = df[(df['Person1']!=df['Person2'])]

#len(df[(df['Related']==1)])

print(df['Related'].value_counts())
# Out:
# 1    3362
# 0    1561
# Name: Related, dtype: int64

# %% [markdown]
# From value_counts() it is visible that data is imbalanced and there are many more instances of 1 than 0. So, let's create some more instances of class 0 between two families, such that dataframe becomes balanced

# %%
extra = df['Related'].value_counts()[1]-df['Related'].value_counts()[0]
while extra>=0:
    rows = df.sample(n=2)
    first = rows.iloc[0,:]
    second = rows.iloc[1,:]
    
    if first.Family1!=second.Family1 and first.Family2!=second.Family2:
        new1 = {'Family1':first.Family1,'Person1':first.Person1,'Family2':second.Family1,'Person2':second.Person1,'Related':0}
        extra=extra-1
        if extra==0:
            break
        new2 = {'Family1':first.Family2,'Person1':first.Person2,'Family2':second.Family2,'Person2':second.Person2,'Related':0}
        extra=extra-1
        
        df=df.append(new1,ignore_index=True)
        df=df.append(new2,ignore_index=True)

# %% [markdown]
# Now all rows with 1 are together and all rows with 0 are together, Rows should be shuffled

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df['Related'].value_counts()
# Out:
# 1    3362
# 0    3361
# Name: Related, dtype: int64

# %% [markdown]
# The dataset is now balanced

# %%
df.head()
# Out:
#   Family1 Person1 Family2 Person2  Related
# 0   F0332    MID1   F0332    MID4        1
# 1   F0191    MID1   F0191    MID4        1
# 2   F0020   MID11   F0020   MID10        1
# 3   F0536    MID2   F0536    MID5        1
# 4   F0809    MID5   F0809    MID3        1

# %%
df.to_csv('my_csv.csv')

# %%
df = pd.read_csv("./my_csv.csv")
df.head()
# Out:
#   Family1 Person1 Family2 Person2  Related
# 0   F0332    MID1   F0332    MID4        1
# 1   F0191    MID1   F0191    MID4        1
# 2   F0020   MID11   F0020   MID10        1
# 3   F0536    MID2   F0536    MID5        1
# 4   F0809    MID5   F0809    MID3        1

# %% [markdown]
# # Custom Dataset Class

# %%
class FamilyDataset(Dataset):
    """Family Dataset."""

    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.relations = df
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.relations)
    
    def __getpair__(self,idx):
        pair = self.root_dir+self.relations.iloc[idx,0] + '/' + self.relations.iloc[idx,1],\
        self.root_dir+self.relations.iloc[idx,2] + '/' + self.relations.iloc[idx,3]
#         print(pair)
        return pair
    
    def __getlabel__(self,idx):
        return self.relations.iloc[idx,4]
    
    def __getitem__(self, idx):
        pair =  self.__getpair__(idx)
        label = self.__getlabel__(idx)
        
        first = random.choice(os.listdir(pair[0]))
        second = random.choice(os.listdir(pair[1]))
        
        img0 = Image.open(pair[0] + '/' + first)
        img1 = Image.open(pair[1] + '/'  + second)
#         img0 = img0.convert("L")
#         img1 = img1.convert("L")
        
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
            
        return idx,img0,img1,label

# %%
train_df,valid_df = np.split(df, [int(.8*len(df))])

# %%
train_transform = transforms.Compose([transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])])

valid_transform = transforms.Compose([transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])])

train_dataset= FamilyDataset(df=train_df,root_dir="./recognizing-faces-in-the-wild/train/",transform=train_transform)
valid_dataset = FamilyDataset(df=valid_df,root_dir="./recognizing-faces-in-the-wild/train/",transform=valid_transform)

# %% [markdown]
# # Visualising Data

# %%
vis_dataloader = DataLoader(train_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)
dataiter = iter(vis_dataloader)

example_batch = next(dataiter)
concatenated = torch.cat((example_batch[1],example_batch[2]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[3].numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0 1 1 0 1 1]

# %% [markdown]
# # Defining Neural Network

# %%
# class SiameseNetwork(nn.Module):
#     def __init__(self):
#         super(SiameseNetwork, self).__init__()
#         self.cnn1 = nn.Sequential(
#             nn.ReflectionPad2d(1),
#             nn.Conv2d(1, 4, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(4),
            
#             nn.ReflectionPad2d(1),
#             nn.Conv2d(4, 8, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(8),

#             nn.ReflectionPad2d(1),
#             nn.Conv2d(8, 8, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(8),

#         )

#         self.fc1 = nn.Sequential(
#             nn.Linear(8*224*224, 1024),
#             nn.ReLU(inplace=True),

#             nn.Linear(1024, 1024),
#             nn.ReLU(inplace=True),
            
#             nn.Linear(1024, 512),
#             nn.ReLU(inplace=True),
            
#             nn.Linear(512, 512),
#             nn.ReLU(inplace=True),
            
#             nn.Linear(512, 50),
#             nn.ReLU(inplace=True),
            
#             nn.Linear(50, 25))
        
#         self.fc2 = nn.Sequential(
#             nn.Linear(25,2)
#         )
        
#     def forward_once(self, x):
#         output = self.cnn1(x)
#         output = output.view(output.size()[0], -1)
#         output = self.fc1(output)
#         return output

#     def forward(self, input1, input2):
#         output1 = self.forward_once(input1)
#         output2 = self.forward_once(input2)
        
#         euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        
#         output = self.fc2(output1-output2)
        
#         return output

# %% [markdown]
# # VGG Face Net

# %%
class Vgg_face_dag(nn.Module):

    def __init__(self):
        super(Vgg_face_dag, self).__init__()
        self.meta = {'mean': [129.186279296875, 104.76238250732422, 93.59396362304688],
                     'std': [1, 1, 1],
                     'imageSize': [224, 224, 3]}
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_1 = nn.ReLU(inplace=True)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_2 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)

        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_1 = nn.ReLU(inplace=True)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)

        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_1 = nn.ReLU(inplace=True)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_2 = nn.ReLU(inplace=True)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_3 = nn.ReLU(inplace=True)
        self.pool3 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)

        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_1 = nn.ReLU(inplace=True)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_2 = nn.ReLU(inplace=True)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_3 = nn.ReLU(inplace=True)
        self.pool4 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_1 = nn.ReLU(inplace=True)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_2 = nn.ReLU(inplace=True)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_3 = nn.ReLU(inplace=True)
        self.pool5 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        
        self.fc6 = nn.Linear(in_features=25088, out_features=4096, bias=True)
        self.relu6 = nn.ReLU(inplace=True)
        self.dropout6 = nn.Dropout(p=0.5)
        self.fc7 = nn.Linear(in_features=4096, out_features=4096, bias=True)
        self.relu7 = nn.ReLU(inplace=True)
        self.dropout7 = nn.Dropout(p=0.5)
        self.fc8 = nn.Linear(in_features=4096, out_features=2622, bias=True)

    def forward_once(self, x0):
        x1 = self.conv1_1(x0)
        x2 = self.relu1_1(x1)
        x3 = self.conv1_2(x2)
        x4 = self.relu1_2(x3)
        x5 = self.pool1(x4)
        x6 = self.conv2_1(x5)
        x7 = self.relu2_1(x6)
        x8 = self.conv2_2(x7)
        x9 = self.relu2_2(x8)
        x10 = self.pool2(x9)
        x11 = self.conv3_1(x10)
        x12 = self.relu3_1(x11)
        x13 = self.conv3_2(x12)
        x14 = self.relu3_2(x13)
        x15 = self.conv3_3(x14)
        x16 = self.relu3_3(x15)
        x17 = self.pool3(x16)
        x18 = self.conv4_1(x17)
        x19 = self.relu4_1(x18)
        x20 = self.conv4_2(x19)
        x21 = self.relu4_2(x20)
        x22 = self.conv4_3(x21)
        x23 = self.relu4_3(x22)
        x24 = self.pool4(x23)
        x25 = self.conv5_1(x24)
        x26 = self.relu5_1(x25)
        x27 = self.conv5_2(x26)
        x28 = self.relu5_2(x27)
        x29 = self.conv5_3(x28)
        x30 = self.relu5_3(x29)
        x31_preflatten = self.pool5(x30)
        x31 = x31_preflatten.view(x31_preflatten.size(0), -1)
        x32 = self.fc6(x31)
        x33 = self.relu6(x32)
        x34 = self.dropout6(x33)
        x35 = self.fc7(x34)
        x36 = self.relu7(x35)
        x37 = self.dropout7(x36)
        x38 = self.fc8(x37)
        return x38
    
    def forward(self,input1,input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        
        #euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        difference = output1 - output2
        return difference

def vgg_face_dag(weights_path=None, **kwargs):
    """
    load imported model instance

    Args:
        weights_path (str): If set, loads model weights from the given path
    """
    model = Vgg_face_dag()
    if weights_path:
        state_dict = torch.load(weights_path)
        model.load_state_dict(state_dict)
    return model

# %%
vggnet = vgg_face_dag(weights_path="./pytorch-pretrained-models-for-face-detection/VGG Face")
vggnet = vggnet.cuda()
for param in vggnet.parameters(): 
    param.requires_grad = False

# %%
# if train_on_gpu:
#     net = SiameseNetwork().cuda()
# else:
#     net= SiameseNetwork()

# %% [markdown]
# # Classification Model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Sequential(
            nn.Linear(2622, 1024),
            nn.ReLU(inplace=True),
            
            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),

            nn.Linear(128, 2))
  
    def forward(self, x):
        x = self.fc1(x)
        return x

# %%
#model = Model().cuda()
#net = nn.Sequential(vgg_face_dag(weights_path="../input/pytorch-pretrained-models-for-face-detection/VGG Face").cuda(),Model().cuda())
net = Model().cuda()

# %% [markdown]
# # Optimizer

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.008, momentum=0.9)

# %% [markdown]
# # Configuration Class

# %%
class Config():
    training_dir = "./recognizing-faces-in-the-wild/train/"
    testing_dir = "./recognizing-faces-in-the-wild/test/"
    batch_size = 64
    train_number_epochs = 150
    num_workers = 0

# %% [markdown]
# # Training and Validation Dataloader

# %%
# # percentage of training set to use as validation
# valid_size = 0.2

# # obtain training indices that will be used for validation
# num_train = len(train_dataset)
# indices = list(range(num_train))
# np.random.shuffle(indices)
# split = int(np.floor(valid_size * num_train))
# train_idx, valid_idx = indices[split:], indices[:split]

# # define samplers for obtaining training and validation batches
# train_sampler = SubsetRandomSampler(train_idx)
# valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=True,num_workers=Config.num_workers, batch_size = Config.batch_size)
valid_loader = torch.utils.data.DataLoader(valid_dataset,shuffle=True,num_workers=Config.num_workers, batch_size = Config.batch_size)

# %%
print(len(valid_loader))
# Out:
# 22

# %% [markdown]
# # Training the model

# %%
train_counter = []
train_loss_history = []
train_iteration_number= 0

valid_counter = []
valid_loss_history = []
valid_iteration_number= 0

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

train_class_correct = list(0 for i in range(2))
train_class_total = list(0 for i in range(2))

valid_class_correct = list(0 for i in range(2))
valid_class_total = list(0 for i in range(2))

# %%
for i in train_loader:
    a=2

# %%
for epoch in range(0,Config.train_number_epochs):
    train_loss = 0.0
    valid_loss = 0.0
    net.train()
    for i, data in enumerate(train_loader,0):
        row, img0, img1 , label = data
        row, img0, img1 , label = row.cuda(), img0.cuda(), img1.cuda() , label.cuda()
        
        optimizer.zero_grad()
        output1= vggnet(img0,img1)
        output = net(output1)
        _, pred= torch.max(output,1)

        loss = criterion(output,label)
        loss.backward()
        
        optimizer.step()
        
        correct = pred.eq(label.view_as(pred))
        for j in range(len(label)):
                        target = label[j].data
                        train_class_correct[target] += correct[j].item()
                        train_class_total[target] += 1
                        
        if i%30 == 0:
            print("Epoch number {}\n Current loss {}\n".format(epoch+1,loss.item()))
            train_iteration_number +=30
            train_counter.append(train_iteration_number)
            train_loss_history.append(loss.item())

            for i in range(2):
                if train_class_total[i] > 0:
                        print('\nTraining Accuracy of %5s: %2d%% (%2d/%2d)' % (
                            str(i), 100 * train_class_correct[i] / train_class_total[i],
                            np.sum(train_class_correct[i]), np.sum(train_class_total[i])))

            print('\nTraining Accuracy (Overall): %2d%% (%2d/%2d)' % (
                100. * np.sum(train_class_correct) / np.sum(train_class_total),
                np.sum(train_class_correct), np.sum(train_class_total)))
    
    net.eval()
    for i, data in enumerate(valid_loader,0):
        row, img0, img1 , label = data
        row, img0, img1 , label = row.cuda(), img0.cuda(), img1.cuda() , label.cuda()
        
        output1= vggnet(img0,img1)
        output = net(output1)
        #combined = torch.cat([vgg,res1,sen1],1)
        #output= net(combined)
        _, pred= torch.max(output,1)

        loss = criterion(output,label)
        
        correct = pred.eq(label.view_as(pred))
        for j in range(len(label)):
                        target = label[j].data
                        valid_class_correct[target] += correct[j].item()
                        valid_class_total[target] += 1
        valid_loss += loss.item()                
        if i%30 == 0:
            print("Epoch number {}\n Current loss {}\n".format(epoch+1,loss.item()))
            valid_iteration_number +=30
            valid_counter.append(valid_iteration_number)
            valid_loss_history.append(loss.item())

            for i in range(2):
                if train_class_total[i] > 0:
                        print('\nValdiation Accuracy of %5s: %2d%% (%2d/%2d)' % (
                            str(i), 100 * valid_class_correct[i] / valid_class_total[i],
                            np.sum(valid_class_correct[i]), np.sum(valid_class_total[i])))

            print('\nValdiation Accuracy (Overall): %2d%% (%2d/%2d)' % (
                100. * np.sum(valid_class_correct) / np.sum(valid_class_total),
                np.sum(valid_class_correct), np.sum(valid_class_total)))
            
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(net.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch number 1
#  Current loss 0.6934438347816467
#
#
# Training Accuracy of     0:  0% ( 0/32)
#
# Training Accuracy of     1: 100% (32/32)
#
# Training Accuracy (Overall): 50% (32/64)
# Epoch number 1
#  Current loss 0.6913734078407288
#
#
# Training Accuracy of     0:  0% ( 0/935)
#
# Training Accuracy of     1: 100% (1049/1049)
#
# Training Accuracy (Overall): 52% (1049/1984)
# Epoch number 1
#  Current loss 0.6973947882652283
#
#
# Training Accuracy of     0:  0% ( 0/1890)
#
# Training Accuracy of     1: 100% (2014/2014)
#
# Training Accuracy (Overall): 51% (2014/3904)
# Epoch number 1
#  Current loss 0.6853286623954773
#
#
# Valdiation Accuracy of     0: 100% (43/43)
#
# Valdiation Accuracy of     1:  0% ( 0/21)
#
# Valdiation Accuracy (Overall): 67% (43/64)
# Validation loss decreased (inf --> 15.204142).  Saving model ...
# Epoch number 2
#  Current loss 0.6955687999725342
#
#
# Training Accuracy of     0: 14% (380/2680)
#
# Training Accuracy of     1: 85% (2372/2762)
#
# Training Accuracy (Overall): 50% (2752/5442)
# Epoch number 2
#  Current loss 0.699817955493927
#
#
# Training Accuracy of     0: 13% (494/3594)
#
# Training Accuracy of     1: 85% (3236/3768)
#
# Training Accuracy (Overall): 50% (3730/7362)
# Epoch number 2
#  Current loss 0.6929236054420471
#
#
# Training Accuracy of     0: 13% (623/4573)
#
# Training Accuracy of     1: 85% (4047/4709)
#
# Training Accuracy (Overall): 50% (4670/9282)
# Epoch number 2
#  Current loss 0.6932770013809204
#
#
# Valdiation Accuracy of     0: 95% (710/743)
#
# Valdiation Accuracy of     1:  4% (31/666)
#
# Valdiation Accuracy (Overall): 52% (741/1409)
# Epoch number 3
#  Current loss 0.6926796436309814
#
#
# Training Accuracy of     0: 24% (1284/5330)
#
# Training Accuracy of     1: 75% (4139/5490)
#
# Training Accuracy (Overall): 50% (5423/10820)
# Epoch number 3
#  Current loss 0.6926684379577637
#
#
# Training Accuracy of     0: 20% (1284/6273)
#
# Training Accuracy of     1: 79% (5116/6467)
#
# Training Accuracy (Overall): 50% (6400/12740)
# Epoch number 3
#  Current loss 0.6932321786880493
#
#
# Training Accuracy of     0: 17% (1284/7217)
#
# Training Accuracy of     1: 81% (6092/7443)
#
# Training Accuracy (Overall): 50% (7376/14660)
# Epoch number 3
#  Current loss 0.6957181692123413
#
#
# Valdiation Accuracy of     0: 48% (710/1463)
#
# Valdiation Accuracy of     1: 50% (656/1291)
#
# Valdiation Accuracy (Overall): 49% (1366/2754)
# Epoch number 4
#  Current loss 0.6936201453208923
#
#
# Training Accuracy of     0: 16% (1284/7987)
#
# Training Accuracy of     1: 83% (6860/8211)
#
# Training Accuracy (Overall): 50% (8144/16198)
# Epoch number 4
#  Current loss 0.6911484599113464
#
#
# Training Accuracy of     0: 14% (1284/8901)
#
# Training Accuracy of     1: 85% (7866/9217)
#
# Training Accuracy (Overall): 50% (9150/18118)
# Epoch number 4
#  Current loss 0.6932235360145569
#
#
# Training Accuracy of     0: 13% (1284/9853)
#
# Training Accuracy of     1: 86% (8834/10185)
#
# Training Accuracy (Overall): 50% (10118/20038)
# Epoch number 4
#  Current loss 0.6913039088249207
#
#
# Valdiation Accuracy of     0: 34% (747/2167)
#
# Valdiation Accuracy of     1: 65% (1270/1932)
#
# Valdiation Accuracy (Overall): 49% (2017/4099)
# Epoch number 5
#  Current loss 0.6928126215934753
#
#
# Training Accuracy of     0: 16% (1728/10637)
#
# Training Accuracy of     1: 83% (9133/10939)
#
# Training Accuracy (Overall): 50% (10861/21576)
# Epoch number 5
#  Current loss 0.6945035457611084
#
#
# Training Accuracy of     0: 18% (2193/11592)
#
# Training Accuracy of     1: 80% (9623/11904)
#
# Training Accuracy (Overall): 50% (11816/23496)
# Epoch number 5
#  Current loss 0.6938382387161255
#
#
# Training Accuracy of     0: 17% (2196/12534)
#
# Training Accuracy of     1: 82% (10601/12882)
#
# Training Accuracy (Overall): 50% (12797/25416)
# Epoch number 5
#  Current loss 0.6866976022720337
#
#
# Valdiation Accuracy of     0: 49% (1420/2864)
#
# Valdiation Accuracy of     1: 50% (1310/2580)
#
# Valdiation Accuracy (Overall): 50% (2730/5444)
# Epoch number 6
#  Current loss 0.6966559290885925
#
#
# Training Accuracy of     0: 16% (2196/13291)
#
# Training Accuracy of     1: 83% (11382/13663)
#
# Training Accuracy (Overall): 50% (13578/26954)
# Epoch number 6
#  Current loss 0.6934232711791992
#
#
# Training Accuracy of     0: 15% (2196/14244)
#
# Training Accuracy of     1: 84% (12349/14630)
#
# Training Accuracy (Overall): 50% (14545/28874)
# Epoch number 6
#  Current loss 0.6924808025360107
#
#
# Training Accuracy of     0: 17% (2627/15189)
#
# Training Accuracy of     1: 82% (12859/15605)
#
# Training Accuracy (Overall): 50% (15486/30794)
# Epoch number 6
#  Current loss 0.6934646368026733
#
#
# Valdiation Accuracy of     0: 39% (1420/3582)
#
# Valdiation Accuracy of     1: 60% (1937/3207)
#
# Valdiation Accuracy (Overall): 49% (3357/6789)
# Epoch number 7
#  Current loss 0.6964952945709229
#
#
# Training Accuracy of     0: 16% (2627/15941)
#
# Training Accuracy of     1: 83% (13645/16391)
#
# Training Accuracy (Overall): 50% (16272/32332)
# Epoch number 7
#  Current loss 0.6913814544677734
#
#
# Training Accuracy of     0: 15% (2627/16865)
#
# Training Accuracy of     1: 84% (14641/17387)
#
# Training Accuracy (Overall): 50% (17268/34252)
# Epoch number 7
#  Current loss 0.6871288418769836
#
#
# Training Accuracy of     0: 14% (2627/17814)
#
# Training Accuracy of     1: 85% (15612/18358)
#
# Training Accuracy (Overall): 50% (18239/36172)
# Epoch number 7
#  Current loss 0.6936517357826233
#
#
# Valdiation Accuracy of     0: 33% (1449/4289)
#
# Valdiation Accuracy of     1: 66% (2540/3845)
#
# Valdiation Accuracy (Overall): 49% (3989/8134)
# Epoch number 8
#  Current loss 0.6932256817817688
#
#
# Training Accuracy of     0: 14% (2719/18588)
#
# Training Accuracy of     1: 85% (16288/19122)
#
# Training Accuracy (Overall): 50% (19007/37710)
# Epoch number 8
#  Current loss 0.692531168460846
#
#
# Training Accuracy of     0: 17% (3458/19532)
#
# Training Accuracy of     1: 82% (16524/20098)
#
# Training Accuracy (Overall): 50% (19982/39630)
# Epoch number 8
#  Current loss 0.6929016709327698
#
#
# Training Accuracy of     0: 16% (3480/20488)
#
# Training Accuracy of     1: 82% (17474/21062)
#
# Training Accuracy (Overall): 50% (20954/41550)
# Epoch number 8
#  Current loss 0.695222020149231
#
#
# Valdiation Accuracy of     0: 42% (2130/5005)
#
# Valdiation Accuracy of     1: 57% (2569/4474)
#
# Valdiation Accuracy (Overall): 49% (4699/9479)
# Epoch number 9
#  Current loss 0.6904807686805725
#
#
# Training Accuracy of     0: 16% (3497/21236)
#
# Training Accuracy of     1: 83% (18253/21852)
#
# Training Accuracy (Overall): 50% (21750/43088)
# Epoch number 9
#  Current loss 0.6940430998802185
#
#
# Training Accuracy of     0: 16% (3627/22210)
#
# Training Accuracy of     1: 83% (19078/22798)
#
# Training Accuracy (Overall): 50% (22705/45008)
# Epoch number 9
#  Current loss 0.6913554668426514
#
#
# Training Accuracy of     0: 17% (4146/23135)
#
# Training Accuracy of     1: 82% (19527/23793)
#
# Training Accuracy (Overall): 50% (23673/46928)
# Epoch number 9
#  Current loss 0.6957434415817261
#
#
# Valdiation Accuracy of     0: 37% (2130/5716)
#
# Valdiation Accuracy of     1: 62% (3203/5108)
#
# Valdiation Accuracy (Overall): 49% (5333/10824)
# Epoch number 10
#  Current loss 0.6950904726982117
#
#
# Training Accuracy of     0: 17% (4146/23894)
#
# Training Accuracy of     1: 82% (20306/24572)
#
# Training Accuracy (Overall): 50% (24452/48466)
# Epoch number 10
#  Current loss 0.6917647123336792
#
#
# Training Accuracy of     0: 16% (4146/24842)
#
# Training Accuracy of     1: 83% (21278/25544)
#
# Training Accuracy (Overall): 50% (25424/50386)
# Epoch number 10
#  Current loss 0.6919869780540466
#
#
# Training Accuracy of     0: 18% (4842/25816)
#
# Training Accuracy of     1: 81% (21525/26490)
#
# Training Accuracy (Overall): 50% (26367/52306)
# Epoch number 10
#  Current loss 0.7030165195465088
#
#
# Valdiation Accuracy of     0: 33% (2130/6430)
#
# Valdiation Accuracy of     1: 66% (3834/5739)
#
# Valdiation Accuracy (Overall): 49% (5964/12169)
# Epoch number 11
#  Current loss 0.6923317313194275
#
#
# Training Accuracy of     0: 18% (4944/26541)
#
# Training Accuracy of     1: 81% (22212/27303)
#
# Training Accuracy (Overall): 50% (27156/53844)
# Epoch number 11
#  Current loss 0.6837410926818848
#
#
# Training Accuracy of     0: 18% (4944/27449)
#
# Training Accuracy of     1: 82% (23224/28315)
#
# Training Accuracy (Overall): 50% (28168/55764)
# Epoch number 11
#  Current loss 0.6947845220565796
#
#
# Training Accuracy of     0: 18% (5245/28445)
#
# Training Accuracy of     1: 81% (23883/29239)
#
# Training Accuracy (Overall): 50% (29128/57684)
# Epoch number 11
#  Current loss 0.6926377415657043
# Valdiation Accuracy of     0: 30% (2157/7134)
#
# Valdiation Accuracy of     1: 69% (4458/6380)
#
# Valdiation Accuracy (Overall): 48% (6615/13514)
# Epoch number 12
#  Current loss 0.6926040053367615
#
#
# Training Accuracy of     0: 20% (5897/29193)
#
# Training Accuracy of     1: 79% (23973/30029)
#
# Training Accuracy (Overall): 50% (29870/59222)
# Epoch number 12
#  Current loss 0.6883589029312134
#
#
# Training Accuracy of     0: 21% (6579/30100)
#
# Training Accuracy of     1: 78% (24255/31042)
#
# Training Accuracy (Overall): 50% (30834/61142)
# Epoch number 12
#  Current loss 0.6984958052635193
#
#
# Training Accuracy of     0: 21% (6579/31071)
#
# Training Accuracy of     1: 78% (25204/31991)
#
# Training Accuracy (Overall): 50% (31783/63062)
# Epoch number 12
#  Current loss 0.6936173439025879
#
#
# Valdiation Accuracy of     0: 34% (2724/7839)
#
# Valdiation Accuracy of     1: 66% (4696/7020)
#
# Valdiation Accuracy (Overall): 49% (7420/14859)
# Epoch number 13
#  Current loss 0.6910623908042908
#
#
# Training Accuracy of     0: 22% (7140/31848)
#
# Training Accuracy of     1: 77% (25421/32752)
#
# Training Accuracy (Overall): 50% (32561/64600)
# Epoch number 13
#  Current loss 0.6933411955833435
#
#
# Training Accuracy of     0: 21% (7194/32787)
#
# Training Accuracy of     1: 78% (26344/33733)
#
# Training Accuracy (Overall): 50% (33538/66520)
# Epoch number 13
#  Current loss 0.6932520866394043
#
#
# Training Accuracy of     0: 21% (7368/33756)
#
# Training Accuracy of     1: 78% (27137/34684)
#
# Training Accuracy (Overall): 50% (34505/68440)
# Epoch number 13
#  Current loss 0.6902838945388794
#
#
# Valdiation Accuracy of     0: 39% (3405/8549)
#
# Valdiation Accuracy of     1: 61% (4731/7655)
#
# Valdiation Accuracy (Overall): 50% (8136/16204)
# Epoch number 14
#  Current loss 0.6887596249580383
#
#
# Training Accuracy of     0: 22% (7713/34490)
#
# Training Accuracy of     1: 77% (27603/35488)
#
# Training Accuracy (Overall): 50% (35316/69978)
# Epoch number 14
#  Current loss 0.6891328692436218
#
#
# Training Accuracy of     0: 21% (7713/35430)
#
# Training Accuracy of     1: 78% (28583/36468)
#
# Training Accuracy (Overall): 50% (36296/71898)
# Epoch number 14
#  Current loss 0.6936279535293579
#
#
# Training Accuracy of     0: 21% (7713/36395)
#
# Training Accuracy of     1: 78% (29538/37423)
#
# Training Accuracy (Overall): 50% (37251/73818)
# Epoch number 14
#  Current loss 0.692294180393219
#
#
# Valdiation Accuracy of     0: 36% (3405/9261)
#
# Valdiation Accuracy of     1: 64% (5364/8288)
#
# Valdiation Accuracy (Overall): 49% (8769/17549)
# Epoch number 15
#  Current loss 0.6909621953964233
#
#
# Training Accuracy of     0: 22% (8274/37140)
#
# Training Accuracy of     1: 77% (29786/38216)
#
# Training Accuracy (Overall): 50% (38060/75356)
# Epoch number 15
#  Current loss 0.69096440076828
#
#
# Training Accuracy of     0: 21% (8274/38098)
#
# Training Accuracy of     1: 78% (30748/39178)
#
# Training Accuracy (Overall): 50% (39022/77276)
# Epoch number 15
#  Current loss 0.6913650035858154
#
#
# Training Accuracy of     0: 21% (8531/39061)
#
# Training Accuracy of     1: 78% (31555/40135)
#
# Training Accuracy (Overall): 50% (40086/79196)
# Epoch number 15
#  Current loss 0.6837790608406067
#
#
# Valdiation Accuracy of     0: 34% (3405/9964)
#
# Valdiation Accuracy of     1: 67% (6006/8930)
#
# Valdiation Accuracy (Overall): 49% (9411/18894)
# Epoch number 16
#  Current loss 0.6906232833862305
#
#
# Training Accuracy of     0: 21% (8565/39795)
#
# Training Accuracy of     1: 78% (32336/40939)
#
# Training Accuracy (Overall): 50% (40901/80734)
# Epoch number 16
#  Current loss 0.6926829218864441
#
#
# Training Accuracy of     0: 22% (9029/40762)
#
# Training Accuracy of     1: 78% (32823/41892)
#
# Training Accuracy (Overall): 50% (41852/82654)
# Epoch number 16
#  Current loss 0.6904873847961426
#
#
# Training Accuracy of     0: 21% (9094/41676)
#
# Training Accuracy of     1: 78% (33804/42898)
#
# Training Accuracy (Overall): 50% (42898/84574)
# Epoch number 16
#  Current loss 0.6915069222450256
#
#
# Valdiation Accuracy of     0: 31% (3406/10682)
#
# Valdiation Accuracy of     1: 69% (6633/9557)
#
# Valdiation Accuracy (Overall): 49% (10039/20239)
# Epoch number 17
#  Current loss 0.691503643989563
#
#
# Training Accuracy of     0: 21% (9094/42447)
#
# Training Accuracy of     1: 79% (34571/43665)
#
# Training Accuracy (Overall): 50% (43665/86112)
# Epoch number 17
#  Current loss 0.6904996037483215
#
#
# Training Accuracy of     0: 23% (10020/43403)
#
# Training Accuracy of     1: 77% (34607/44629)
#
# Training Accuracy (Overall): 50% (44627/88032)
# Epoch number 17
#  Current loss 0.6922234892845154
#
#
# Training Accuracy of     0: 23% (10193/44314)
#
# Training Accuracy of     1: 77% (35425/45638)
#
# Training Accuracy (Overall): 50% (45618/89952)
# Epoch number 17
#  Current loss 0.6908023357391357
#
#
# Valdiation Accuracy of     0: 29% (3410/11390)
#
# Valdiation Accuracy of     1: 71% (7270/10194)
#
# Valdiation Accuracy (Overall): 49% (10680/21584)
# Epoch number 18
#  Current loss 0.6890016794204712
#
#
# Training Accuracy of     0: 22% (10193/45090)
#
# Training Accuracy of     1: 77% (36187/46400)
#
# Training Accuracy (Overall): 50% (46380/91490)
# Epoch number 18
#  Current loss 0.6939222812652588
#
#
# Training Accuracy of     0: 22% (10488/46036)
#
# Training Accuracy of     1: 78% (37045/47374)
#
# Training Accuracy (Overall): 50% (47533/93410)
# Epoch number 18
#  Current loss 0.692045271396637
#
#
# Training Accuracy of     0: 24% (11297/47007)
#
# Training Accuracy of     1: 76% (37204/48323)
#
# Training Accuracy (Overall): 50% (48501/95330)
# Epoch number 18
#  Current loss 0.7014811635017395
#
#
# Valdiation Accuracy of     0: 28% (3437/12109)
#
# Valdiation Accuracy of     1: 72% (7896/10820)
#
# Valdiation Accuracy (Overall): 49% (11333/22929)
# Epoch number 19
#  Current loss 0.6869434714317322
#
#
# Training Accuracy of     0: 24% (11599/47746)
#
# Training Accuracy of     1: 76% (37750/49122)
#
# Training Accuracy (Overall): 50% (49349/96868)
# Epoch number 19
#  Current loss 0.6927536725997925
#
#
# Training Accuracy of     0: 23% (11614/48709)
#
# Training Accuracy of     1: 77% (38704/50079)
#
# Training Accuracy (Overall): 50% (50318/98788)
# Epoch number 19
#  Current loss 0.6911274790763855
#
#
# Training Accuracy of     0: 25% (12441/49655)
#
# Training Accuracy of     1: 76% (38912/51053)
#
# Training Accuracy (Overall): 50% (51353/100708)
# Epoch number 19
#  Current loss 0.6913754343986511
#
#
# Valdiation Accuracy of     0: 26% (3437/12811)
#
# Valdiation Accuracy of     1: 74% (8539/11463)
#
# Valdiation Accuracy (Overall): 49% (11976/24274)
# Epoch number 20
#  Current loss 0.683254599571228
#
#
# Training Accuracy of     0: 24% (12527/50396)
#
# Training Accuracy of     1: 76% (39668/51850)
#
# Training Accuracy (Overall): 51% (52195/102246)
# Epoch number 20
#  Current loss 0.6877660155296326
#
#
# Training Accuracy of     0: 24% (12527/51324)
#
# Training Accuracy of     1: 76% (40660/52842)
#
# Training Accuracy (Overall): 51% (53187/104166)
# Epoch number 20
#  Current loss 0.6861609220504761
#
#
# Training Accuracy of     0: 24% (12991/52301)
#
# Training Accuracy of     1: 76% (41305/53785)
#
# Training Accuracy (Overall): 51% (54296/106086)
# Epoch number 20
#  Current loss 0.6915480494499207
#
#
# Valdiation Accuracy of     0: 25% (3455/13528)
#
# Valdiation Accuracy of     1: 75% (9163/12091)
#
# Valdiation Accuracy (Overall): 49% (12618/25619)
# Validation loss decreased (15.204142 --> 15.169462).  Saving model ...
# Epoch number 21
#  Current loss 0.6850543022155762
#
#
# Training Accuracy of     0: 25% (13544/53047)
#
# Training Accuracy of     1: 76% (41652/54577)
#
# Training Accuracy (Overall): 51% (55196/107624)
# Epoch number 21
#  Current loss 0.6862661242485046
#
#
# Training Accuracy of     0: 26% (14245/54004)
#
# Training Accuracy of     1: 75% (42157/55540)
#
# Training Accuracy (Overall): 51% (56402/109544)
# Epoch number 21
#  Current loss 0.6871576309204102
#
#
# Training Accuracy of     0: 27% (14947/54948)
#
# Training Accuracy of     1: 75% (42596/56516)
#
# Training Accuracy (Overall): 51% (57543/111464)
# Epoch number 21
#  Current loss 0.6948513388633728
#
#
# Valdiation Accuracy of     0: 26% (3739/14236)
#
# Valdiation Accuracy of     1: 76% (9707/12728)
#
# Valdiation Accuracy (Overall): 49% (13446/26964)
# Validation loss decreased (15.169462 --> 15.095529).  Saving model ...
# Epoch number 22
#  Current loss 0.6807026267051697
#
#
# Training Accuracy of     0: 27% (15067/55698)
#
# Training Accuracy of     1: 75% (43348/57304)
#
# Training Accuracy (Overall): 51% (58415/113002)
# Epoch number 22
#  Current loss 0.6788368225097656
# Training Accuracy of     0: 26% (15209/56621)
#
# Training Accuracy of     1: 76% (44319/58301)
#
# Training Accuracy (Overall): 51% (59528/114922)
# Epoch number 22
#  Current loss 0.6776828169822693
#
#
# Training Accuracy of     0: 27% (15732/57594)
#
# Training Accuracy of     1: 75% (44960/59248)
#
# Training Accuracy (Overall): 51% (60692/116842)
# Epoch number 22
#  Current loss 0.6920279264450073
#
#
# Valdiation Accuracy of     0: 25% (3843/14950)
#
# Valdiation Accuracy of     1: 77% (10318/13359)
#
# Valdiation Accuracy (Overall): 50% (14161/28309)
# Validation loss decreased (15.095529 --> 14.975462).  Saving model ...
# Epoch number 23
#  Current loss 0.6822826862335205
#
#
# Training Accuracy of     0: 27% (16257/58356)
#
# Training Accuracy of     1: 75% (45372/60024)
#
# Training Accuracy (Overall): 52% (61629/118380)
# Epoch number 23
#  Current loss 0.6748501062393188
#
#
# Training Accuracy of     0: 28% (16838/59299)
#
# Training Accuracy of     1: 75% (46008/61001)
#
# Training Accuracy (Overall): 52% (62846/120300)
# Epoch number 23
#  Current loss 0.6656237840652466
#
#
# Training Accuracy of     0: 28% (17243/60254)
#
# Training Accuracy of     1: 75% (46798/61966)
#
# Training Accuracy (Overall): 52% (64041/122220)
# Epoch number 23
#  Current loss 0.6760794520378113
#
#
# Valdiation Accuracy of     0: 26% (4201/15657)
#
# Valdiation Accuracy of     1: 77% (10803/13997)
#
# Valdiation Accuracy (Overall): 50% (15004/29654)
# Validation loss decreased (14.975462 --> 14.816336).  Saving model ...
# Epoch number 24
#  Current loss 0.6927645206451416
#
#
# Training Accuracy of     0: 28% (17685/61007)
#
# Training Accuracy of     1: 75% (47335/62751)
#
# Training Accuracy (Overall): 52% (65020/123758)
# Epoch number 24
#  Current loss 0.6626735925674438
#
#
# Training Accuracy of     0: 29% (18265/61932)
#
# Training Accuracy of     1: 75% (47944/63746)
#
# Training Accuracy (Overall): 52% (66209/125678)
# Epoch number 24
#  Current loss 0.6247276067733765
#
#
# Training Accuracy of     0: 29% (18819/62872)
#
# Training Accuracy of     1: 75% (48666/64726)
#
# Training Accuracy (Overall): 52% (67485/127598)
# Epoch number 24
#  Current loss 0.6529093384742737
#
#
# Valdiation Accuracy of     0: 27% (4566/16362)
#
# Valdiation Accuracy of     1: 77% (11281/14637)
#
# Valdiation Accuracy (Overall): 51% (15847/30999)
# Validation loss decreased (14.816336 --> 14.118482).  Saving model ...
# Epoch number 25
#  Current loss 0.6743085980415344
#
#
# Training Accuracy of     0: 30% (19261/63651)
#
# Training Accuracy of     1: 75% (49186/65485)
#
# Training Accuracy (Overall): 53% (68447/129136)
# Epoch number 25
#  Current loss 0.6718559265136719
#
#
# Training Accuracy of     0: 30% (19890/64644)
#
# Training Accuracy of     1: 74% (49757/66412)
#
# Training Accuracy (Overall): 53% (69647/131056)
# Epoch number 25
#  Current loss 0.6713991165161133
#
#
# Training Accuracy of     0: 31% (20471/65584)
#
# Training Accuracy of     1: 74% (50418/67392)
#
# Training Accuracy (Overall): 53% (70889/132976)
# Epoch number 25
#  Current loss 0.6619245409965515
#
#
# Valdiation Accuracy of     0: 29% (5038/17082)
#
# Valdiation Accuracy of     1: 76% (11657/15262)
#
# Valdiation Accuracy (Overall): 51% (16695/32344)
# Validation loss decreased (14.118482 --> 13.970108).  Saving model ...
# Epoch number 26
#  Current loss 0.6169353723526001
#
#
# Training Accuracy of     0: 31% (20883/66302)
#
# Training Accuracy of     1: 74% (51024/68212)
#
# Training Accuracy (Overall): 53% (71907/134514)
# Epoch number 26
#  Current loss 0.5758375525474548
#
#
# Training Accuracy of     0: 31% (21461/67270)
#
# Training Accuracy of     1: 74% (51644/69164)
#
# Training Accuracy (Overall): 53% (73105/136434)
# Epoch number 26
#  Current loss 0.6110217571258545
#
#
# Training Accuracy of     0: 32% (22046/68224)
#
# Training Accuracy of     1: 74% (52305/70130)
#
# Training Accuracy (Overall): 53% (74351/138354)
# Epoch number 26
#  Current loss 0.6629254221916199
#
#
# Valdiation Accuracy of     0: 30% (5421/17787)
#
# Valdiation Accuracy of     1: 76% (12127/15902)
#
# Valdiation Accuracy (Overall): 52% (17548/33689)
# Validation loss decreased (13.970108 --> 13.854629).  Saving model ...
# Epoch number 27
#  Current loss 0.5761457085609436
#
#
# Training Accuracy of     0: 32% (22458/68956)
#
# Training Accuracy of     1: 74% (52888/70936)
#
# Training Accuracy (Overall): 53% (75346/139892)
# Epoch number 27
#  Current loss 0.6433783173561096
#
#
# Training Accuracy of     0: 32% (23049/69920)
#
# Training Accuracy of     1: 74% (53554/71892)
#
# Training Accuracy (Overall): 54% (76603/141812)
# Epoch number 27
#  Current loss 0.6279417872428894
#
#
# Training Accuracy of     0: 33% (23586/70853)
#
# Training Accuracy of     1: 74% (54255/72879)
#
# Training Accuracy (Overall): 54% (77841/143732)
# Epoch number 27
#  Current loss 0.6249504089355469
#
#
# Valdiation Accuracy of     0: 31% (5768/18500)
#
# Valdiation Accuracy of     1: 76% (12614/16534)
#
# Valdiation Accuracy (Overall): 52% (18382/35034)
# Validation loss decreased (13.854629 --> 13.405185).  Saving model ...
# Epoch number 28
#  Current loss 0.6412859559059143
#
#
# Training Accuracy of     0: 33% (24018/71602)
#
# Training Accuracy of     1: 74% (54824/73668)
#
# Training Accuracy (Overall): 54% (78842/145270)
# Epoch number 28
#  Current loss 0.6059269309043884
#
#
# Training Accuracy of     0: 33% (24591/72561)
#
# Training Accuracy of     1: 74% (55489/74629)
#
# Training Accuracy (Overall): 54% (80080/147190)
# Epoch number 28
#  Current loss 0.6437893509864807
#
#
# Training Accuracy of     0: 34% (25207/73541)
#
# Training Accuracy of     1: 74% (56134/75569)
#
# Training Accuracy (Overall): 54% (81341/149110)
# Epoch number 28
#  Current loss 0.6422739624977112
#
#
# Valdiation Accuracy of     0: 32% (6151/19208)
#
# Valdiation Accuracy of     1: 76% (13117/17171)
#
# Valdiation Accuracy (Overall): 52% (19268/36379)
# Epoch number 29
#  Current loss 0.6163131594657898
#
#
# Training Accuracy of     0: 34% (25590/74260)
#
# Training Accuracy of     1: 74% (56776/76388)
#
# Training Accuracy (Overall): 54% (82366/150648)
# Epoch number 29
#  Current loss 0.6054779887199402
#
#
# Training Accuracy of     0: 34% (26130/75190)
#
# Training Accuracy of     1: 74% (57500/77378)
#
# Training Accuracy (Overall): 54% (83630/152568)
# Epoch number 29
#  Current loss 0.5640915036201477
#
#
# Training Accuracy of     0: 35% (26680/76127)
#
# Training Accuracy of     1: 74% (58195/78361)
#
# Training Accuracy (Overall): 54% (84875/154488)
# Epoch number 29
#  Current loss 0.6110260486602783
#
#
# Valdiation Accuracy of     0: 32% (6525/19916)
#
# Valdiation Accuracy of     1: 76% (13599/17808)
#
# Valdiation Accuracy (Overall): 53% (20124/37724)
# Epoch number 30
#  Current loss 0.6069974899291992
#
#
# Training Accuracy of     0: 35% (27175/76918)
#
# Training Accuracy of     1: 74% (58717/79108)
#
# Training Accuracy (Overall): 55% (85892/156026)
# Epoch number 30
#  Current loss 0.6262708306312561
#
#
# Training Accuracy of     0: 35% (27780/77864)
#
# Training Accuracy of     1: 74% (59366/80082)
#
# Training Accuracy (Overall): 55% (87146/157946)
# Epoch number 30
#  Current loss 0.5974454879760742
#
#
# Training Accuracy of     0: 35% (28327/78819)
#
# Training Accuracy of     1: 74% (60085/81047)
#
# Training Accuracy (Overall): 55% (88412/159866)
# Epoch number 30
#  Current loss 0.5723987817764282
#
#
# Valdiation Accuracy of     0: 33% (6999/20620)
#
# Valdiation Accuracy of     1: 75% (14019/18449)
#
# Valdiation Accuracy (Overall): 53% (21018/39069)
# Epoch number 31
#  Current loss 0.5746170878410339
#
#
# Training Accuracy of     0: 36% (28765/79553)
#
# Training Accuracy of     1: 74% (60668/81851)
#
# Training Accuracy (Overall): 55% (89433/161404)
# Epoch number 31
#  Current loss 0.5630062222480774
#
#
# Training Accuracy of     0: 36% (29357/80497)
#
# Training Accuracy of     1: 74% (61379/82827)
#
# Training Accuracy (Overall): 55% (90736/163324)
# Epoch number 31
#  Current loss 0.5846335291862488
#
#
# Training Accuracy of     0: 36% (29968/81462)
#
# Training Accuracy of     1: 74% (62032/83782)
#
# Training Accuracy (Overall): 55% (92000/165244)
# Epoch number 31
#  Current loss 0.6526813507080078
#
#
# Valdiation Accuracy of     0: 34% (7363/21335)
#
# Valdiation Accuracy of     1: 76% (14518/19079)
#
# Valdiation Accuracy (Overall): 54% (21881/40414)
# Validation loss decreased (13.405185 --> 13.300414).  Saving model ...
# Epoch number 32
#  Current loss 0.608314037322998
#
#
# Training Accuracy of     0: 36% (30401/82210)
#
# Training Accuracy of     1: 74% (62636/84572)
# Training Accuracy (Overall): 55% (93037/166782)
# Epoch number 32
#  Current loss 0.5780362486839294
#
#
# Training Accuracy of     0: 37% (30952/83166)
#
# Training Accuracy of     1: 74% (63354/85536)
#
# Training Accuracy (Overall): 55% (94306/168702)
# Epoch number 32
#  Current loss 0.6463012099266052
#
#
# Training Accuracy of     0: 37% (31489/84082)
#
# Training Accuracy of     1: 74% (64127/86540)
#
# Training Accuracy (Overall): 56% (95616/170622)
# Epoch number 32
#  Current loss 0.6209548115730286
#
#
# Valdiation Accuracy of     0: 35% (7818/22041)
#
# Valdiation Accuracy of     1: 75% (14965/19718)
#
# Valdiation Accuracy (Overall): 54% (22783/41759)
# Epoch number 33
#  Current loss 0.5968099236488342
#
#
# Training Accuracy of     0: 37% (31992/84860)
#
# Training Accuracy of     1: 74% (64645/87300)
#
# Training Accuracy (Overall): 56% (96637/172160)
# Epoch number 33
#  Current loss 0.5120522379875183
#
#
# Training Accuracy of     0: 37% (32602/85827)
#
# Training Accuracy of     1: 74% (65332/88253)
#
# Training Accuracy (Overall): 56% (97934/174080)
# Epoch number 33
#  Current loss 0.6112977266311646
#
#
# Training Accuracy of     0: 38% (33182/86756)
#
# Training Accuracy of     1: 74% (66073/89244)
#
# Training Accuracy (Overall): 56% (99255/176000)
# Epoch number 33
#  Current loss 0.7463880181312561
#
#
# Valdiation Accuracy of     0: 35% (8159/22759)
#
# Valdiation Accuracy of     1: 76% (15473/20345)
#
# Valdiation Accuracy (Overall): 54% (23632/43104)
# Epoch number 34
#  Current loss 0.6166481971740723
#
#
# Training Accuracy of     0: 38% (33631/87516)
#
# Training Accuracy of     1: 74% (66651/90022)
#
# Training Accuracy (Overall): 56% (100282/177538)
# Epoch number 34
#  Current loss 0.59947669506073
#
#
# Training Accuracy of     0: 38% (34190/88460)
#
# Training Accuracy of     1: 74% (67408/90998)
#
# Training Accuracy (Overall): 56% (101598/179458)
# Epoch number 34
#  Current loss 0.5521485805511475
#
#
# Training Accuracy of     0: 38% (34794/89411)
#
# Training Accuracy of     1: 74% (68102/91967)
#
# Training Accuracy (Overall): 56% (102896/181378)
# Epoch number 34
#  Current loss 0.5970649123191833
#
#
# Valdiation Accuracy of     0: 36% (8508/23465)
#
# Valdiation Accuracy of     1: 76% (15997/20984)
#
# Valdiation Accuracy (Overall): 55% (24505/44449)
# Validation loss decreased (13.300414 --> 13.189186).  Saving model ...
# Epoch number 35
#  Current loss 0.5736952424049377
#
#
# Training Accuracy of     0: 39% (35235/90158)
#
# Training Accuracy of     1: 74% (68700/92758)
#
# Training Accuracy (Overall): 56% (103935/182916)
# Epoch number 35
#  Current loss 0.5646021366119385
#
#
# Training Accuracy of     0: 39% (35847/91102)
#
# Training Accuracy of     1: 74% (69438/93734)
#
# Training Accuracy (Overall): 56% (105285/184836)
# Epoch number 35
#  Current loss 0.6339142918586731
#
#
# Training Accuracy of     0: 39% (36448/92047)
#
# Training Accuracy of     1: 74% (70158/94709)
#
# Training Accuracy (Overall): 57% (106606/186756)
# Epoch number 35
#  Current loss 0.5931040644645691
#
#
# Valdiation Accuracy of     0: 36% (8945/24180)
#
# Valdiation Accuracy of     1: 76% (16472/21614)
#
# Valdiation Accuracy (Overall): 55% (25417/45794)
# Validation loss decreased (13.189186 --> 13.112758).  Saving model ...
# Epoch number 36
#  Current loss 0.5420156717300415
#
#
# Training Accuracy of     0: 39% (36923/92821)
#
# Training Accuracy of     1: 74% (70706/95473)
#
# Training Accuracy (Overall): 57% (107629/188294)
# Epoch number 36
#  Current loss 0.5687291026115417
#
#
# Training Accuracy of     0: 40% (37523/93761)
#
# Training Accuracy of     1: 74% (71412/96453)
#
# Training Accuracy (Overall): 57% (108935/190214)
# Epoch number 36
#  Current loss 0.6231029629707336
#
#
# Training Accuracy of     0: 40% (38090/94701)
#
# Training Accuracy of     1: 74% (72119/97433)
#
# Training Accuracy (Overall): 57% (110209/192134)
# Epoch number 36
#  Current loss 0.6174352765083313
#
#
# Valdiation Accuracy of     0: 37% (9356/24884)
#
# Valdiation Accuracy of     1: 76% (16967/22255)
#
# Valdiation Accuracy (Overall): 55% (26323/47139)
# Epoch number 37
#  Current loss 0.6234908103942871
#
#
# Training Accuracy of     0: 40% (38574/95469)
#
# Training Accuracy of     1: 74% (72688/98203)
#
# Training Accuracy (Overall): 57% (111262/193672)
# Epoch number 37
#  Current loss 0.5164433121681213
#
#
# Training Accuracy of     0: 40% (39182/96413)
#
# Training Accuracy of     1: 74% (73417/99179)
#
# Training Accuracy (Overall): 57% (112599/195592)
# Epoch number 37
#  Current loss 0.6518474817276001
#
#
# Training Accuracy of     0: 40% (39777/97333)
#
# Training Accuracy of     1: 74% (74147/100179)
#
# Training Accuracy (Overall): 57% (113924/197512)
# Epoch number 37
#  Current loss 0.5748925805091858
#
#
# Valdiation Accuracy of     0: 38% (9782/25592)
#
# Valdiation Accuracy of     1: 76% (17473/22892)
#
# Valdiation Accuracy (Overall): 56% (27255/48484)
# Validation loss decreased (13.112758 --> 12.471070).  Saving model ...
# Epoch number 38
#  Current loss 0.537400484085083
#
#
# Training Accuracy of     0: 41% (40283/98111)
#
# Training Accuracy of     1: 74% (74704/100939)
#
# Training Accuracy (Overall): 57% (114987/199050)
# Epoch number 38
#  Current loss 0.582863986492157
#
#
# Training Accuracy of     0: 41% (40866/99035)
#
# Training Accuracy of     1: 74% (75475/101935)
#
# Training Accuracy (Overall): 57% (116341/200970)
# Epoch number 38
#  Current loss 0.5761907696723938
#
#
# Training Accuracy of     0: 41% (41471/99994)
#
# Training Accuracy of     1: 74% (76182/102896)
#
# Training Accuracy (Overall): 57% (117653/202890)
# Epoch number 38
#  Current loss 0.6416564583778381
#
#
# Valdiation Accuracy of     0: 38% (10244/26304)
#
# Valdiation Accuracy of     1: 76% (17945/23525)
#
# Valdiation Accuracy (Overall): 56% (28189/49829)
# Epoch number 39
#  Current loss 0.6138913631439209
#
#
# Training Accuracy of     0: 41% (41990/100767)
#
# Training Accuracy of     1: 74% (76746/103661)
#
# Training Accuracy (Overall): 58% (118736/204428)
# Epoch number 39
#  Current loss 0.47781139612197876
#
#
# Training Accuracy of     0: 41% (42613/101730)
#
# Training Accuracy of     1: 74% (77452/104618)
#
# Training Accuracy (Overall): 58% (120065/206348)
# Epoch number 39
#  Current loss 0.5464634299278259
#
#
# Training Accuracy of     0: 42% (43236/102670)
#
# Training Accuracy of     1: 74% (78188/105598)
#
# Training Accuracy (Overall): 58% (121424/208268)
# Epoch number 39
#  Current loss 0.753142237663269
#
#
# Valdiation Accuracy of     0: 39% (10695/27023)
#
# Valdiation Accuracy of     1: 76% (18434/24151)
#
# Valdiation Accuracy (Overall): 56% (29129/51174)
# Epoch number 40
#  Current loss 0.4990273416042328
#
#
# Training Accuracy of     0: 42% (43701/103416)
#
# Training Accuracy of     1: 74% (78803/106390)
#
# Training Accuracy (Overall): 58% (122504/209806)
# Epoch number 40
#  Current loss 0.597754716873169
#
#
# Training Accuracy of     0: 42% (44268/104369)
#
# Training Accuracy of     1: 74% (79558/107357)
#
# Training Accuracy (Overall): 58% (123826/211726)
# Epoch number 40
#  Current loss 0.5636675953865051
#
#
# Training Accuracy of     0: 42% (44904/105309)
#
# Training Accuracy of     1: 74% (80298/108337)
#
# Training Accuracy (Overall): 58% (125202/213646)
# Epoch number 40
#  Current loss 0.6605907678604126
#
#
# Valdiation Accuracy of     0: 39% (11060/27723)
#
# Valdiation Accuracy of     1: 76% (18976/24796)
#
# Valdiation Accuracy (Overall): 57% (30036/52519)
# Epoch number 41
#  Current loss 0.5216593742370605
#
#
# Training Accuracy of     0: 42% (45410/106080)
#
# Training Accuracy of     1: 74% (80886/109104)
#
# Training Accuracy (Overall): 58% (126296/215184)
# Epoch number 41
#  Current loss 0.5395151972770691
#
#
# Training Accuracy of     0: 43% (46074/107060)
#
# Training Accuracy of     1: 74% (81567/110044)
#
# Training Accuracy (Overall): 58% (127641/217104)
# Epoch number 41
#  Current loss 0.558750331401825
#
#
# Training Accuracy of     0: 43% (46646/107975)
#
# Training Accuracy of     1: 74% (82327/111049)
#
# Training Accuracy (Overall): 58% (128973/219024)
# Epoch number 41
#  Current loss 0.6566270589828491
#
#
# Valdiation Accuracy of     0: 40% (11582/28438)
#
# Valdiation Accuracy of     1: 76% (19358/25426)
#
# Valdiation Accuracy (Overall): 57% (30940/53864)
# Epoch number 42
#  Current loss 0.598436176776886
#
#
# Training Accuracy of     0: 43% (47119/108723)
#
# Training Accuracy of     1: 74% (82942/111839)
#
# Training Accuracy (Overall): 58% (130061/220562)
# Epoch number 42
#  Current loss 0.584023654460907
#
#
# Training Accuracy of     0: 43% (47716/109669)
# Training Accuracy of     1: 74% (83698/112813)
#
# Training Accuracy (Overall): 59% (131414/222482)
# Epoch number 42
#  Current loss 0.5446801781654358
#
#
# Training Accuracy of     0: 43% (48362/110633)
#
# Training Accuracy of     1: 74% (84437/113769)
#
# Training Accuracy (Overall): 59% (132799/224402)
# Epoch number 42
#  Current loss 0.6566259860992432
#
#
# Valdiation Accuracy of     0: 40% (11946/29141)
#
# Valdiation Accuracy of     1: 76% (19884/26068)
#
# Valdiation Accuracy (Overall): 57% (31830/55209)
# Validation loss decreased (12.471070 --> 12.460274).  Saving model ...
# Epoch number 43
#  Current loss 0.5584642887115479
#
#
# Training Accuracy of     0: 43% (48835/111372)
#
# Training Accuracy of     1: 74% (85045/114568)
#
# Training Accuracy (Overall): 59% (133880/225940)
# Epoch number 43
#  Current loss 0.5328956246376038
#
#
# Training Accuracy of     0: 44% (49495/112342)
#
# Training Accuracy of     1: 74% (85737/115518)
#
# Training Accuracy (Overall): 59% (135232/227860)
# Epoch number 43
#  Current loss 0.5490118861198425
#
#
# Training Accuracy of     0: 44% (50097/113257)
#
# Training Accuracy of     1: 74% (86502/116523)
#
# Training Accuracy (Overall): 59% (136599/229780)
# Epoch number 43
#  Current loss 0.6153604984283447
#
#
# Valdiation Accuracy of     0: 41% (12484/29849)
#
# Valdiation Accuracy of     1: 75% (20288/26705)
#
# Valdiation Accuracy (Overall): 57% (32772/56554)
# Epoch number 44
#  Current loss 0.5387582778930664
#
#
# Training Accuracy of     0: 44% (50605/114027)
#
# Training Accuracy of     1: 74% (87093/117291)
#
# Training Accuracy (Overall): 59% (137698/231318)
# Epoch number 44
#  Current loss 0.5395961999893188
#
#
# Training Accuracy of     0: 44% (51185/114961)
#
# Training Accuracy of     1: 74% (87872/118277)
#
# Training Accuracy (Overall): 59% (139057/233238)
# Epoch number 44
#  Current loss 0.6607052087783813
#
#
# Training Accuracy of     0: 44% (51841/115937)
#
# Training Accuracy of     1: 74% (88571/119221)
#
# Training Accuracy (Overall): 59% (140412/235158)
# Epoch number 44
#  Current loss 0.5268241763114929
#
#
# Valdiation Accuracy of     0: 42% (12933/30564)
#
# Valdiation Accuracy of     1: 76% (20777/27335)
#
# Valdiation Accuracy (Overall): 58% (33710/57899)
# Epoch number 45
#  Current loss 0.5961359143257141
#
#
# Training Accuracy of     0: 44% (52306/116671)
#
# Training Accuracy of     1: 74% (89204/120025)
#
# Training Accuracy (Overall): 59% (141510/236696)
# Epoch number 45
#  Current loss 0.6692049503326416
#
#
# Training Accuracy of     0: 44% (52868/117570)
#
# Training Accuracy of     1: 74% (90047/121046)
#
# Training Accuracy (Overall): 59% (142915/238616)
# Epoch number 45
#  Current loss 0.6364835500717163
#
#
# Training Accuracy of     0: 45% (53531/118557)
#
# Training Accuracy of     1: 74% (90734/121979)
#
# Training Accuracy (Overall): 59% (144265/240536)
# Epoch number 45
#  Current loss 0.5889487862586975
#
#
# Valdiation Accuracy of     0: 42% (13375/31270)
#
# Valdiation Accuracy of     1: 76% (21262/27974)
#
# Valdiation Accuracy (Overall): 58% (34637/59244)
# Validation loss decreased (12.460274 --> 12.189788).  Saving model ...
# Epoch number 46
#  Current loss 0.5048578977584839
#
#
# Training Accuracy of     0: 45% (54043/119327)
#
# Training Accuracy of     1: 74% (91320/122747)
#
# Training Accuracy (Overall): 60% (145363/242074)
# Epoch number 46
#  Current loss 0.4679129719734192
#
#
# Training Accuracy of     0: 45% (54649/120274)
#
# Training Accuracy of     1: 74% (92078/123720)
#
# Training Accuracy (Overall): 60% (146727/243994)
# Epoch number 46
#  Current loss 0.5154370665550232
#
#
# Training Accuracy of     0: 45% (55300/121232)
#
# Training Accuracy of     1: 74% (92831/124682)
#
# Training Accuracy (Overall): 60% (148131/245914)
# Epoch number 46
#  Current loss 0.6208281517028809
#
#
# Valdiation Accuracy of     0: 43% (13829/31984)
#
# Valdiation Accuracy of     1: 76% (21770/28605)
#
# Valdiation Accuracy (Overall): 58% (35599/60589)
# Epoch number 47
#  Current loss 0.4511435329914093
#
#
# Training Accuracy of     0: 45% (55802/121987)
#
# Training Accuracy of     1: 74% (93417/125465)
#
# Training Accuracy (Overall): 60% (149219/247452)
# Epoch number 47
#  Current loss 0.52128005027771
#
#
# Training Accuracy of     0: 45% (56425/122940)
#
# Training Accuracy of     1: 74% (94140/126432)
#
# Training Accuracy (Overall): 60% (150565/249372)
# Epoch number 47
#  Current loss 0.6237168908119202
#
#
# Training Accuracy of     0: 46% (57002/123858)
#
# Training Accuracy of     1: 74% (94924/127434)
#
# Training Accuracy (Overall): 60% (151926/251292)
# Epoch number 47
#  Current loss 0.49336159229278564
#
#
# Valdiation Accuracy of     0: 44% (14383/32687)
#
# Valdiation Accuracy of     1: 75% (22131/29247)
#
# Valdiation Accuracy (Overall): 58% (36514/61934)
# Epoch number 48
#  Current loss 0.4963856637477875
#
#
# Training Accuracy of     0: 46% (57525/124627)
#
# Training Accuracy of     1: 74% (95526/128203)
#
# Training Accuracy (Overall): 60% (153051/252830)
# Epoch number 48
#  Current loss 0.640603244304657
#
#
# Training Accuracy of     0: 46% (58137/125583)
#
# Training Accuracy of     1: 74% (96269/129167)
#
# Training Accuracy (Overall): 60% (154406/254750)
# Epoch number 48
#  Current loss 0.5466237664222717
#
#
# Training Accuracy of     0: 46% (58763/126526)
#
# Training Accuracy of     1: 74% (97026/130144)
#
# Training Accuracy (Overall): 60% (155789/256670)
# Epoch number 48
#  Current loss 0.6385212540626526
#
#
# Valdiation Accuracy of     0: 44% (14898/33399)
#
# Valdiation Accuracy of     1: 75% (22562/29880)
#
# Valdiation Accuracy (Overall): 59% (37460/63279)
# Epoch number 49
#  Current loss 0.5506415963172913
#
#
# Training Accuracy of     0: 46% (59250/127275)
#
# Training Accuracy of     1: 74% (97646/130933)
#
# Training Accuracy (Overall): 60% (156896/258208)
# Epoch number 49
#  Current loss 0.5337191224098206
#
#
# Training Accuracy of     0: 46% (59921/128245)
#
# Training Accuracy of     1: 74% (98377/131883)
#
# Training Accuracy (Overall): 60% (158298/260128)
# Epoch number 49
#  Current loss 0.5463929176330566
#
#
# Training Accuracy of     0: 46% (60547/129190)
#
# Training Accuracy of     1: 74% (99143/132858)
#
# Training Accuracy (Overall): 60% (159690/262048)
# Epoch number 49
#  Current loss 0.5108963847160339
#
#
# Valdiation Accuracy of     0: 45% (15393/34111)
#
# Valdiation Accuracy of     1: 75% (22986/30513)
#
# Valdiation Accuracy (Overall): 59% (38379/64624)
# Epoch number 50
#  Current loss 0.4820203185081482
#
#
# Training Accuracy of     0: 46% (61030/129930)
#
# Training Accuracy of     1: 74% (99786/133656)
#
# Training Accuracy (Overall): 61% (160816/263586)
# Epoch number 50
#  Current loss 0.5282544493675232
#
#
# Training Accuracy of     0: 47% (61611/130863)
#
# Training Accuracy of     1: 74% (100562/134643)
#
# Training Accuracy (Overall): 61% (162173/265506)
# Epoch number 50
#  Current loss 0.576509952545166
#
#
# Training Accuracy of     0: 47% (62243/131811)
#
# Training Accuracy of     1: 74% (101317/135615)
#
# Training Accuracy (Overall): 61% (163560/267426)
# Epoch number 50
#  Current loss 0.5920298099517822
#
#
# Valdiation Accuracy of     0: 45% (15912/34820)
#
# Valdiation Accuracy of     1: 75% (23414/31149)
#
# Valdiation Accuracy (Overall): 59% (39326/65969)
# Epoch number 51
#  Current loss 0.5399534106254578
#
#
# Training Accuracy of     0: 47% (62792/132582)
#
# Training Accuracy of     1: 74% (101908/136382)
#
# Training Accuracy (Overall): 61% (164700/268964)
# Epoch number 51
#  Current loss 0.4987261891365051
#
#
# Training Accuracy of     0: 47% (63455/133561)
#
# Training Accuracy of     1: 74% (102606/137323)
#
# Training Accuracy (Overall): 61% (166061/270884)
# Epoch number 51
#  Current loss 0.5875625610351562
#
#
# Training Accuracy of     0: 47% (64059/134486)
#
# Training Accuracy of     1: 74% (103391/138318)
#
# Training Accuracy (Overall): 61% (167450/272804)
# Epoch number 51
#  Current loss 0.5884178876876831
#
#
# Valdiation Accuracy of     0: 45% (16266/35533)
#
# Valdiation Accuracy of     1: 75% (23945/31781)
#
# Valdiation Accuracy (Overall): 59% (40211/67314)
# Epoch number 52
#  Current loss 0.6090081930160522
#
#
# Training Accuracy of     0: 47% (64538/135230)
#
# Training Accuracy of     1: 74% (104001/139112)
#
# Training Accuracy (Overall): 61% (168539/274342)
# Epoch number 52
#  Current loss 0.6227242350578308
#
#
# Training Accuracy of     0: 47% (65152/136153)
#
# Training Accuracy of     1: 74% (104773/140109)
#
# Training Accuracy (Overall): 61% (169925/276262)
# Epoch number 52
#  Current loss 0.4580538868904114
# Training Accuracy of     0: 47% (65783/137095)
#
# Training Accuracy of     1: 74% (105553/141087)
#
# Training Accuracy (Overall): 61% (171336/278182)
# Epoch number 52
#  Current loss 0.633308470249176
#
#
# Valdiation Accuracy of     0: 46% (16697/36245)
#
# Valdiation Accuracy of     1: 75% (24436/32414)
#
# Valdiation Accuracy (Overall): 59% (41133/68659)
# Epoch number 53
#  Current loss 0.4919632077217102
#
#
# Training Accuracy of     0: 48% (66331/137881)
#
# Training Accuracy of     1: 74% (106126/141839)
#
# Training Accuracy (Overall): 61% (172457/279720)
# Epoch number 53
#  Current loss 0.5720721483230591
#
#
# Training Accuracy of     0: 48% (66975/138832)
#
# Training Accuracy of     1: 74% (106906/142808)
#
# Training Accuracy (Overall): 61% (173881/281640)
# Epoch number 53
#  Current loss 0.42064499855041504
#
#
# Training Accuracy of     0: 48% (67603/139763)
#
# Training Accuracy of     1: 74% (107676/143797)
#
# Training Accuracy (Overall): 61% (175279/283560)
# Epoch number 53
#  Current loss 0.6926715970039368
#
#
# Valdiation Accuracy of     0: 46% (17146/36949)
#
# Valdiation Accuracy of     1: 75% (24913/33055)
#
# Valdiation Accuracy (Overall): 60% (42059/70004)
# Epoch number 54
#  Current loss 0.6028091311454773
#
#
# Training Accuracy of     0: 48% (68136/140530)
#
# Training Accuracy of     1: 74% (108256/144568)
#
# Training Accuracy (Overall): 61% (176392/285098)
# Epoch number 54
#  Current loss 0.4968257248401642
#
#
# Training Accuracy of     0: 48% (68756/141466)
#
# Training Accuracy of     1: 74% (109037/145552)
#
# Training Accuracy (Overall): 61% (177793/287018)
# Epoch number 54
#  Current loss 0.5485552549362183
#
#
# Training Accuracy of     0: 48% (69406/142409)
#
# Training Accuracy of     1: 74% (109794/146529)
#
# Training Accuracy (Overall): 62% (179200/288938)
# Epoch number 54
#  Current loss 0.5665233731269836
#
#
# Valdiation Accuracy of     0: 46% (17683/37658)
#
# Valdiation Accuracy of     1: 75% (25288/33691)
#
# Valdiation Accuracy (Overall): 60% (42971/71349)
# Epoch number 55
#  Current loss 0.5960052609443665
#
#
# Training Accuracy of     0: 48% (69934/143183)
#
# Training Accuracy of     1: 74% (110373/147293)
#
# Training Accuracy (Overall): 62% (180307/290476)
# Epoch number 55
#  Current loss 0.5657872557640076
#
#
# Training Accuracy of     0: 48% (70537/144129)
#
# Training Accuracy of     1: 74% (111092/148267)
#
# Training Accuracy (Overall): 62% (181629/292396)
# Epoch number 55
#  Current loss 0.5027456879615784
#
#
# Training Accuracy of     0: 49% (71207/145093)
#
# Training Accuracy of     1: 74% (111838/149223)
#
# Training Accuracy (Overall): 62% (183045/294316)
# Epoch number 55
#  Current loss 0.6375433206558228
#
#
# Valdiation Accuracy of     0: 47% (18229/38376)
#
# Valdiation Accuracy of     1: 74% (25670/34318)
#
# Valdiation Accuracy (Overall): 60% (43899/72694)
# Epoch number 56
#  Current loss 0.6065000295639038
#
#
# Training Accuracy of     0: 49% (71700/145842)
#
# Training Accuracy of     1: 74% (112448/150012)
#
# Training Accuracy (Overall): 62% (184148/295854)
# Epoch number 56
#  Current loss 0.5091872215270996
#
#
# Training Accuracy of     0: 49% (72357/146792)
#
# Training Accuracy of     1: 74% (113189/150982)
#
# Training Accuracy (Overall): 62% (185546/297774)
# Epoch number 56
#  Current loss 0.5739801526069641
#
#
# Training Accuracy of     0: 49% (72986/147730)
#
# Training Accuracy of     1: 75% (113974/151964)
#
# Training Accuracy (Overall): 62% (186960/299694)
# Epoch number 56
#  Current loss 0.514397144317627
#
#
# Valdiation Accuracy of     0: 47% (18737/39083)
#
# Valdiation Accuracy of     1: 74% (26092/34956)
#
# Valdiation Accuracy (Overall): 60% (44829/74039)
# Epoch number 57
#  Current loss 0.4397577941417694
#
#
# Training Accuracy of     0: 49% (73502/148496)
#
# Training Accuracy of     1: 75% (114580/152736)
#
# Training Accuracy (Overall): 62% (188082/301232)
# Epoch number 57
#  Current loss 0.3718622922897339
#
#
# Training Accuracy of     0: 49% (74155/149444)
#
# Training Accuracy of     1: 75% (115323/153708)
#
# Training Accuracy (Overall): 62% (189478/303152)
# Epoch number 57
#  Current loss 0.5550712943077087
#
#
# Training Accuracy of     0: 49% (74747/150371)
#
# Training Accuracy of     1: 75% (116119/154701)
#
# Training Accuracy (Overall): 62% (190866/305072)
# Epoch number 57
#  Current loss 0.6835464835166931
#
#
# Valdiation Accuracy of     0: 48% (19187/39800)
#
# Valdiation Accuracy of     1: 74% (26582/35584)
#
# Valdiation Accuracy (Overall): 60% (45769/75384)
# Epoch number 58
#  Current loss 0.4729044735431671
#
#
# Training Accuracy of     0: 49% (75284/151137)
#
# Training Accuracy of     1: 75% (116734/155473)
#
# Training Accuracy (Overall): 62% (192018/306610)
# Epoch number 58
#  Current loss 0.5143293142318726
#
#
# Training Accuracy of     0: 49% (75951/152097)
#
# Training Accuracy of     1: 75% (117507/156433)
#
# Training Accuracy (Overall): 62% (193458/308530)
# Epoch number 58
#  Current loss 0.3997901380062103
#
#
# Training Accuracy of     0: 50% (76610/153048)
#
# Training Accuracy of     1: 75% (118279/157402)
#
# Training Accuracy (Overall): 62% (194889/310450)
# Epoch number 58
#  Current loss 0.6318920254707336
#
#
# Valdiation Accuracy of     0: 48% (19640/40505)
#
# Valdiation Accuracy of     1: 74% (27071/36224)
#
# Valdiation Accuracy (Overall): 60% (46711/76729)
# Epoch number 59
#  Current loss 0.5072956085205078
#
#
# Training Accuracy of     0: 50% (77109/153789)
#
# Training Accuracy of     1: 75% (118927/158199)
#
# Training Accuracy (Overall): 62% (196036/311988)
# Epoch number 59
#  Current loss 0.5853025913238525
#
#
# Training Accuracy of     0: 50% (77703/154688)
#
# Training Accuracy of     1: 75% (119780/159220)
#
# Training Accuracy (Overall): 62% (197483/313908)
# Epoch number 59
#  Current loss 0.6830910444259644
#
#
# Training Accuracy of     0: 50% (78372/155649)
#
# Training Accuracy of     1: 75% (120533/160179)
#
# Training Accuracy (Overall): 62% (198905/315828)
# Epoch number 59
#  Current loss 0.5028988122940063
#
#
# Valdiation Accuracy of     0: 48% (19972/41216)
#
# Valdiation Accuracy of     1: 74% (27635/36858)
#
# Valdiation Accuracy (Overall): 60% (47607/78074)
# Epoch number 60
#  Current loss 0.6148067712783813
#
#
# Training Accuracy of     0: 50% (78885/156437)
#
# Training Accuracy of     1: 75% (121070/160929)
#
# Training Accuracy (Overall): 63% (199955/317366)
# Epoch number 60
#  Current loss 0.46655890345573425
#
#
# Training Accuracy of     0: 50% (79509/157368)
#
# Training Accuracy of     1: 75% (121842/161918)
#
# Training Accuracy (Overall): 63% (201351/319286)
# Epoch number 60
#  Current loss 0.3996538519859314
#
#
# Training Accuracy of     0: 50% (80181/158339)
#
# Training Accuracy of     1: 75% (122604/162867)
#
# Training Accuracy (Overall): 63% (202785/321206)
# Epoch number 60
#  Current loss 0.6745173335075378
#
#
# Valdiation Accuracy of     0: 49% (20578/41919)
#
# Valdiation Accuracy of     1: 74% (27930/37500)
#
# Valdiation Accuracy (Overall): 61% (48508/79419)
# Epoch number 61
#  Current loss 0.49598875641822815
#
#
# Training Accuracy of     0: 50% (80682/159093)
#
# Training Accuracy of     1: 75% (123234/163651)
#
# Training Accuracy (Overall): 63% (203916/322744)
# Epoch number 61
#  Current loss 0.4905721843242645
#
#
# Training Accuracy of     0: 50% (81326/160019)
#
# Training Accuracy of     1: 75% (124017/164645)
#
# Training Accuracy (Overall): 63% (205343/324664)
# Epoch number 61
#  Current loss 0.5334427356719971
#
# ...
# Epoch number 131
#  Current loss 0.48590460419654846
#
#
# Training Accuracy of     0: 62% (217064/344659)
#
# Training Accuracy of     1: 78% (279711/354545)
#
# Training Accuracy (Overall): 71% (496775/699204)
# Epoch number 131
#  Current loss 0.5931275486946106
#
#
# Training Accuracy of     0: 63% (217793/345608)
#
# Training Accuracy of     1: 78% (280538/355516)
#
# Training Accuracy (Overall): 71% (498331/701124)
# Epoch number 131
#  Current loss 0.3431011140346527
#
#
# Training Accuracy of     0: 63% (218551/346579)
#
# Training Accuracy of     1: 78% (281336/356465)
#
# Training Accuracy (Overall): 71% (499887/703044)
# Epoch number 131
#  Current loss 0.5428762435913086
#
#
# Valdiation Accuracy of     0: 58% (54284/92331)
#
# Valdiation Accuracy of     1: 72% (59712/82583)
#
# Valdiation Accuracy (Overall): 65% (113996/174914)
# Epoch number 132
#  Current loss 0.43798133730888367
#
#
# Training Accuracy of     0: 63% (219131/347323)
#
# Training Accuracy of     1: 78% (282026/357259)
#
# Training Accuracy (Overall): 71% (501157/704582)
# Epoch number 132
#  Current loss 0.45526862144470215
#
#
# Training Accuracy of     0: 63% (219848/348273)
#
# Training Accuracy of     1: 78% (282821/358229)
#
# Training Accuracy (Overall): 71% (502669/706502)
# Epoch number 132
#  Current loss 0.4526001811027527
#
#
# Training Accuracy of     0: 63% (220541/349183)
#
# Training Accuracy of     1: 78% (283680/359239)
#
# Training Accuracy (Overall): 71% (504221/708422)
# Epoch number 132
#  Current loss 0.6787955164909363
#
#
# Valdiation Accuracy of     0: 58% (54662/93042)
#
# Valdiation Accuracy of     1: 72% (60250/83217)
#
# Valdiation Accuracy (Overall): 65% (114912/176259)
# Epoch number 133
#  Current loss 0.42308351397514343
#
#
# Training Accuracy of     0: 63% (221136/349967)
#
# Training Accuracy of     1: 78% (284308/359993)
#
# Training Accuracy (Overall): 71% (505444/709960)
# Epoch number 133
#  Current loss 0.4988658130168915
#
#
# Training Accuracy of     0: 63% (221863/350906)
#
# Training Accuracy of     1: 78% (285143/360974)
#
# Training Accuracy (Overall): 71% (507006/711880)
# Epoch number 133
#  Current loss 0.35929152369499207
#
#
# Training Accuracy of     0: 63% (222581/351847)
#
# Training Accuracy of     1: 79% (285964/361953)
#
# Training Accuracy (Overall): 71% (508545/713800)
# Epoch number 133
#  Current loss 0.6397138833999634
#
#
# Valdiation Accuracy of     0: 58% (55019/93749)
#
# Valdiation Accuracy of     1: 72% (60805/83855)
#
# Valdiation Accuracy (Overall): 65% (115824/177604)
# Epoch number 134
#  Current loss 0.4253222942352295
#
#
# Training Accuracy of     0: 63% (223174/352607)
#
# Training Accuracy of     1: 79% (286625/362731)
#
# Training Accuracy (Overall): 71% (509799/715338)
# Epoch number 134
#  Current loss 0.3420547544956207
#
#
# Training Accuracy of     0: 63% (223908/353531)
#
# Training Accuracy of     1: 79% (287468/363727)
#
# Training Accuracy (Overall): 71% (511376/717258)
# Epoch number 134
#  Current loss 0.4387422800064087
#
#
# Training Accuracy of     0: 63% (224631/354472)
#
# Training Accuracy of     1: 79% (288304/364706)
#
# Training Accuracy (Overall): 71% (512935/719178)
# Epoch number 134
#  Current loss 0.6730037927627563
# Valdiation Accuracy of     0: 58% (55597/94463)
#
# Valdiation Accuracy of     1: 72% (61156/84486)
#
# Valdiation Accuracy (Overall): 65% (116753/178949)
# Epoch number 135
#  Current loss 0.3452604413032532
#
#
# Training Accuracy of     0: 63% (225259/355263)
#
# Training Accuracy of     1: 79% (288933/365453)
#
# Training Accuracy (Overall): 71% (514192/720716)
# Epoch number 135
#  Current loss 0.41266730427742004
#
#
# Training Accuracy of     0: 63% (225982/356189)
#
# Training Accuracy of     1: 79% (289785/366447)
#
# Training Accuracy (Overall): 71% (515767/722636)
# Epoch number 135
#  Current loss 0.4201403558254242
#
#
# Training Accuracy of     0: 63% (226745/357151)
#
# Training Accuracy of     1: 79% (290603/367405)
#
# Training Accuracy (Overall): 71% (517348/724556)
# Epoch number 135
#  Current loss 0.6847172379493713
#
#
# Valdiation Accuracy of     0: 58% (55990/95170)
#
# Valdiation Accuracy of     1: 72% (61692/85124)
#
# Valdiation Accuracy (Overall): 65% (117682/180294)
# Epoch number 136
#  Current loss 0.5713587403297424
#
#
# Training Accuracy of     0: 63% (227356/357920)
#
# Training Accuracy of     1: 79% (291249/368174)
#
# Training Accuracy (Overall): 71% (518605/726094)
# Epoch number 136
#  Current loss 0.4462863802909851
#
#
# Training Accuracy of     0: 63% (228108/358883)
#
# Training Accuracy of     1: 79% (292057/369131)
#
# Training Accuracy (Overall): 71% (520165/728014)
# Epoch number 136
#  Current loss 0.5016639232635498
#
#
# Training Accuracy of     0: 63% (228812/359794)
#
# Training Accuracy of     1: 79% (292938/370140)
#
# Training Accuracy (Overall): 71% (521750/729934)
# Epoch number 136
#  Current loss 0.6000503301620483
#
#
# Valdiation Accuracy of     0: 58% (56293/95887)
#
# Valdiation Accuracy of     1: 72% (62285/85752)
#
# Valdiation Accuracy (Overall): 65% (118578/181639)
# Epoch number 137
#  Current loss 0.4003075659275055
#
#
# Training Accuracy of     0: 63% (229424/360569)
#
# Training Accuracy of     1: 79% (293582/370903)
#
# Training Accuracy (Overall): 71% (523006/731472)
# Epoch number 137
#  Current loss 0.4467458426952362
#
#
# Training Accuracy of     0: 63% (230111/361488)
#
# Training Accuracy of     1: 79% (294431/371904)
#
# Training Accuracy (Overall): 71% (524542/733392)
# Epoch number 137
#  Current loss 0.3146618604660034
#
#
# Training Accuracy of     0: 63% (230855/362437)
#
# Training Accuracy of     1: 79% (295256/372875)
#
# Training Accuracy (Overall): 71% (526111/735312)
# Epoch number 137
#  Current loss 0.710460901260376
#
#
# Valdiation Accuracy of     0: 58% (56668/96595)
#
# Valdiation Accuracy of     1: 72% (62827/86389)
#
# Valdiation Accuracy (Overall): 65% (119495/182984)
# Epoch number 138
#  Current loss 0.33882859349250793
#
#
# Training Accuracy of     0: 63% (231500/363223)
#
# Training Accuracy of     1: 79% (295909/373627)
#
# Training Accuracy (Overall): 71% (527409/736850)
# Epoch number 138
#  Current loss 0.45472535490989685
#
#
# Training Accuracy of     0: 63% (232244/364162)
#
# Training Accuracy of     1: 79% (296763/374608)
#
# Training Accuracy (Overall): 71% (529007/738770)
# Epoch number 138
#  Current loss 0.4413071870803833
#
#
# Training Accuracy of     0: 63% (232977/365100)
#
# Training Accuracy of     1: 79% (297576/375590)
#
# Training Accuracy (Overall): 71% (530553/740690)
# Epoch number 138
#  Current loss 0.5663700103759766
#
#
# Valdiation Accuracy of     0: 58% (57186/97301)
#
# Valdiation Accuracy of     1: 72% (63254/87028)
#
# Valdiation Accuracy (Overall): 65% (120440/184329)
# Epoch number 139
#  Current loss 0.3561253249645233
#
#
# Training Accuracy of     0: 63% (233598/365869)
#
# Training Accuracy of     1: 79% (298251/376359)
#
# Training Accuracy (Overall): 71% (531849/742228)
# Epoch number 139
#  Current loss 0.2738476097583771
#
#
# Training Accuracy of     0: 63% (234379/366847)
#
# Training Accuracy of     1: 79% (299012/377301)
#
# Training Accuracy (Overall): 71% (533391/744148)
# Epoch number 139
#  Current loss 0.33438512682914734
#
#
# Training Accuracy of     0: 63% (235118/367775)
#
# Training Accuracy of     1: 79% (299882/378293)
#
# Training Accuracy (Overall): 71% (535000/746068)
# Epoch number 139
#  Current loss 0.5747068524360657
#
#
# Valdiation Accuracy of     0: 58% (57685/98018)
#
# Valdiation Accuracy of     1: 72% (63715/87656)
#
# Valdiation Accuracy (Overall): 65% (121400/185674)
# Epoch number 140
#  Current loss 0.4341137111186981
#
#
# Training Accuracy of     0: 63% (235717/368523)
#
# Training Accuracy of     1: 79% (300550/379083)
#
# Training Accuracy (Overall): 71% (536267/747606)
# Epoch number 140
#  Current loss 0.4253883361816406
#
#
# Training Accuracy of     0: 64% (236477/369473)
#
# Training Accuracy of     1: 79% (301372/380053)
#
# Training Accuracy (Overall): 71% (537849/749526)
# Epoch number 140
#  Current loss 0.3694208562374115
#
#
# Training Accuracy of     0: 64% (237201/370398)
#
# Training Accuracy of     1: 79% (302238/381048)
#
# Training Accuracy (Overall): 71% (539439/751446)
# Epoch number 140
#  Current loss 0.6160672307014465
#
#
# Valdiation Accuracy of     0: 59% (58278/98730)
#
# Valdiation Accuracy of     1: 72% (64028/88289)
#
# Valdiation Accuracy (Overall): 65% (122306/187019)
# Epoch number 141
#  Current loss 0.3579818308353424
#
#
# Training Accuracy of     0: 64% (237810/371171)
#
# Training Accuracy of     1: 79% (302882/381813)
#
# Training Accuracy (Overall): 71% (540692/752984)
# Epoch number 141
#  Current loss 0.3210799992084503
#
#
# Training Accuracy of     0: 64% (238570/372118)
#
# Training Accuracy of     1: 79% (303720/382786)
#
# Training Accuracy (Overall): 71% (542290/754904)
# Epoch number 141
#  Current loss 0.39561930298805237
#
#
# Training Accuracy of     0: 64% (239367/373090)
#
# Training Accuracy of     1: 79% (304530/383734)
#
# Training Accuracy (Overall): 71% (543897/756824)
# Epoch number 141
#  Current loss 0.7074549198150635
#
#
# Valdiation Accuracy of     0: 59% (58738/99434)
#
# Valdiation Accuracy of     1: 72% (64515/88930)
#
# Valdiation Accuracy (Overall): 65% (123253/188364)
# Epoch number 142
#  Current loss 0.4169083833694458
#
#
# Training Accuracy of     0: 64% (239955/373825)
#
# Training Accuracy of     1: 79% (305229/384537)
#
# Training Accuracy (Overall): 71% (545184/758362)
# Epoch number 142
#  Current loss 0.29456937313079834
#
#
# Training Accuracy of     0: 64% (240685/374761)
#
# Training Accuracy of     1: 79% (306038/385521)
#
# Training Accuracy (Overall): 71% (546723/760282)
# Epoch number 142
#  Current loss 0.43840593099594116
#
#
# Training Accuracy of     0: 64% (241451/375724)
#
# Training Accuracy of     1: 79% (306857/386478)
#
# Training Accuracy (Overall): 71% (548308/762202)
# Epoch number 142
#  Current loss 0.6560088992118835
#
#
# Valdiation Accuracy of     0: 59% (59230/100147)
#
# Valdiation Accuracy of     1: 72% (64978/89562)
#
# Valdiation Accuracy (Overall): 65% (124208/189709)
# Epoch number 143
#  Current loss 0.3430834114551544
#
#
# Training Accuracy of     0: 64% (242049/376472)
#
# Training Accuracy of     1: 79% (307533/387268)
#
# Training Accuracy (Overall): 71% (549582/763740)
# Epoch number 143
#  Current loss 0.4486163258552551
#
#
# Training Accuracy of     0: 64% (242793/377421)
#
# Training Accuracy of     1: 79% (308345/388239)
#
# Training Accuracy (Overall): 71% (551138/765660)
# Epoch number 143
#  Current loss 0.42877355217933655
#
#
# Training Accuracy of     0: 64% (243532/378371)
#
# Training Accuracy of     1: 79% (309162/389209)
#
# Training Accuracy (Overall): 72% (552694/767580)
# Epoch number 143
#  Current loss 0.6949912309646606
#
#
# Valdiation Accuracy of     0: 59% (59669/100850)
#
# Valdiation Accuracy of     1: 72% (65490/90204)
#
# Valdiation Accuracy (Overall): 65% (125159/191054)
# Epoch number 144
#  Current loss 0.3666553199291229
#
#
# Training Accuracy of     0: 64% (244123/379125)
#
# Training Accuracy of     1: 79% (309840/389993)
#
# Training Accuracy (Overall): 72% (553963/769118)
# Epoch number 144
#  Current loss 0.3714359402656555
#
#
# Training Accuracy of     0: 64% (244870/380058)
#
# Training Accuracy of     1: 79% (310686/390980)
#
# Training Accuracy (Overall): 72% (555556/771038)
# Epoch number 144
#  Current loss 0.37533333897590637
#
#
# Training Accuracy of     0: 64% (245619/380995)
#
# Training Accuracy of     1: 79% (311528/391963)
#
# Training Accuracy (Overall): 72% (557147/772958)
# Epoch number 144
#  Current loss 0.8754191398620605
#
#
# Valdiation Accuracy of     0: 59% (60129/101565)
#
# Valdiation Accuracy of     1: 72% (65964/90834)
#
# Valdiation Accuracy (Overall): 65% (126093/192399)
# Epoch number 145
#  Current loss 0.29221808910369873
# Training Accuracy of     0: 64% (246248/381769)
#
# Training Accuracy of     1: 79% (312181/392727)
#
# Training Accuracy (Overall): 72% (558429/774496)
# Epoch number 145
#  Current loss 0.45788663625717163
#
#
# Training Accuracy of     0: 64% (246999/382720)
#
# Training Accuracy of     1: 79% (312991/393696)
#
# Training Accuracy (Overall): 72% (559990/776416)
# Epoch number 145
#  Current loss 0.5027171969413757
#
#
# Training Accuracy of     0: 64% (247714/383668)
#
# Training Accuracy of     1: 79% (313808/394668)
#
# Training Accuracy (Overall): 72% (561522/778336)
# Epoch number 145
#  Current loss 0.6544631719589233
#
#
# Valdiation Accuracy of     0: 59% (60669/102268)
#
# Valdiation Accuracy of     1: 72% (66361/91476)
#
# Valdiation Accuracy (Overall): 65% (127030/193744)
# Epoch number 146
#  Current loss 0.3617844879627228
#
#
# Training Accuracy of     0: 64% (248311/384426)
#
# Training Accuracy of     1: 79% (314469/395448)
#
# Training Accuracy (Overall): 72% (562780/779874)
# Epoch number 146
#  Current loss 0.5346216559410095
#
#
# Training Accuracy of     0: 64% (249049/385360)
#
# Training Accuracy of     1: 79% (315271/396434)
#
# Training Accuracy (Overall): 72% (564320/781794)
# Epoch number 146
#  Current loss 0.43584418296813965
#
#
# Training Accuracy of     0: 64% (249829/386343)
#
# Training Accuracy of     1: 79% (316046/397371)
#
# Training Accuracy (Overall): 72% (565875/783714)
# Epoch number 146
#  Current loss 0.6601742506027222
#
#
# Valdiation Accuracy of     0: 59% (61215/102987)
#
# Valdiation Accuracy of     1: 72% (66729/92102)
#
# Valdiation Accuracy (Overall): 65% (127944/195089)
# Epoch number 147
#  Current loss 0.40904808044433594
#
#
# Training Accuracy of     0: 64% (250392/387076)
#
# Training Accuracy of     1: 79% (316742/398176)
#
# Training Accuracy (Overall): 72% (567134/785252)
# Epoch number 147
#  Current loss 0.5060562491416931
#
#
# Training Accuracy of     0: 64% (251097/388028)
#
# Training Accuracy of     1: 79% (317484/399144)
#
# Training Accuracy (Overall): 72% (568581/787172)
# Epoch number 147
#  Current loss 0.4190192222595215
#
#
# Training Accuracy of     0: 64% (251783/388969)
#
# Training Accuracy of     1: 79% (318311/400123)
#
# Training Accuracy (Overall): 72% (570094/789092)
# Epoch number 147
#  Current loss 0.5596586465835571
#
#
# Valdiation Accuracy of     0: 59% (61712/103692)
#
# Valdiation Accuracy of     1: 72% (67194/92742)
#
# Valdiation Accuracy (Overall): 65% (128906/196434)
# Epoch number 148
#  Current loss 0.4031907320022583
#
#
# Training Accuracy of     0: 64% (252414/389728)
#
# Training Accuracy of     1: 79% (318990/400902)
#
# Training Accuracy (Overall): 72% (571404/790630)
# Epoch number 148
#  Current loss 0.44166621565818787
#
#
# Training Accuracy of     0: 64% (253166/390681)
#
# Training Accuracy of     1: 79% (319789/401869)
#
# Training Accuracy (Overall): 72% (572955/792550)
# Epoch number 148
#  Current loss 0.32623207569122314
#
#
# Training Accuracy of     0: 64% (253899/391622)
#
# Training Accuracy of     1: 79% (320654/402848)
#
# Training Accuracy (Overall): 72% (574553/794470)
# Epoch number 148
#  Current loss 0.7562196850776672
#
#
# Valdiation Accuracy of     0: 59% (62085/104405)
#
# Valdiation Accuracy of     1: 72% (67753/93374)
#
# Valdiation Accuracy (Overall): 65% (129838/197779)
# Epoch number 149
#  Current loss 0.356690376996994
#
#
# Training Accuracy of     0: 64% (254517/392387)
#
# Training Accuracy of     1: 79% (321321/403621)
#
# Training Accuracy (Overall): 72% (575838/796008)
# Epoch number 149
#  Current loss 0.4347383975982666
#
#
# Training Accuracy of     0: 64% (255267/393342)
#
# Training Accuracy of     1: 79% (322100/404586)
#
# Training Accuracy (Overall): 72% (577367/797928)
# Epoch number 149
#  Current loss 0.44577348232269287
#
#
# Training Accuracy of     0: 64% (255983/394277)
#
# Training Accuracy of     1: 79% (322957/405571)
#
# Training Accuracy (Overall): 72% (578940/799848)
# Epoch number 149
#  Current loss 0.5902690291404724
#
#
# Valdiation Accuracy of     0: 59% (62623/105111)
#
# Valdiation Accuracy of     1: 72% (68154/94013)
#
# Valdiation Accuracy (Overall): 65% (130777/199124)
# Epoch number 150
#  Current loss 0.5679088234901428
#
#
# Training Accuracy of     0: 64% (256590/395033)
#
# Training Accuracy of     1: 79% (323631/406353)
#
# Training Accuracy (Overall): 72% (580221/801386)
# Epoch number 150
#  Current loss 0.39495939016342163
#
#
# Training Accuracy of     0: 64% (257327/395967)
#
# Training Accuracy of     1: 79% (324461/407339)
#
# Training Accuracy (Overall): 72% (581788/803306)
# Epoch number 150
#  Current loss 0.3494051694869995
#
#
# Training Accuracy of     0: 65% (258083/396932)
#
# Training Accuracy of     1: 79% (325273/408294)
#
# Training Accuracy (Overall): 72% (583356/805226)
# Epoch number 150
#  Current loss 0.6989527344703674
#
#
# Valdiation Accuracy of     0: 59% (63158/105827)
#
# Valdiation Accuracy of     1: 72% (68576/94642)
#
# Valdiation Accuracy (Overall): 65% (131734/200469)

# %% [markdown]
# # Training and Validation Loss

# %%
print('\n Training Loss History')
show_plot(train_counter,train_loss_history)

print('\n Validation Loss History')
show_plot(valid_counter,valid_loss_history)
# Out:
#  Training Loss History
#  Validation Loss History

# %% [markdown]
# # Loading Saved Model

# %%
net.load_state_dict(torch.load('model.pt'))

# %% [markdown]
# Now that our model is trained, we'll see how the sample submissions are

# %%
sample_submission = pd.read_csv("../input/recognizing-faces-in-the-wild/sample_submission.csv")
sample_submission.head()

# %%
new = sample_submission["img_pair"].str.split("-", n = 1, expand = True)

# making separate first name column from new data frame 
sample_submission["Person1"]= new[0]
# making separate last name column from new data frame 
sample_submission["Person2"]= new[1]

# Dropping old Name columns
sample_submission.head()

# %% [markdown]
# # Custom Test Dataset

# %%
class FamilyTestDataset(Dataset):
    """Family Dataset."""

    def __init__(self, df, root_dir, transform=None):
        """
        Args:
            df (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.relations = df
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.relations)
    
    def __getpair__(self,idx):
        pair = self.root_dir+self.relations.iloc[idx,2],\
        self.root_dir+self.relations.iloc[idx,3]
        return pair
    
    def __getlabel__(self,idx):
        return self.relations.iloc[idx,4]
    
    def __getitem__(self, idx):
        pair =  self.__getpair__(idx)
        
        img0 = Image.open(pair[0])
        img1 = Image.open(pair[1])
#         img0 = img0.convert("L")
#         img1 = img1.convert("L")
        
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
            
        return idx,img0,img1

# %%
transform = transforms.Compose([transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])])

test_dataset= FamilyTestDataset(df=sample_submission,root_dir="../input/recognizing-faces-in-the-wild/test/",transform=transform)

# %%
test_loader = torch.utils.data.DataLoader(test_dataset,shuffle=True,num_workers=Config.num_workers, batch_size = Config.batch_size)

# %%
net.eval()
for i, data in enumerate(test_loader,0):
    row, img0, img1 = data
    row, img0, img1 = row.cuda(), img0.cuda(), img1.cuda()
   
    output1= vggnet(img0,img1)
    output = net(output1)
    #output= net(img0,img1)
    _, pred= torch.max(output,1)
     
    count=0
    for item in row:
        sample_submission.loc[item,'is_related'] = pred[count].item()
        count+=1

# %%
sample_submission.drop(columns =["Person1","Person2"], inplace = True)

# %%
sample_submission['is_related'].value_counts()

# %%
output= sample_submission.to_csv('output.csv',index=False)

# %%
# import the modules we'll need
from IPython.display import HTML
import base64

# function that takes in a dataframe and creates a text link to  
# download it (will only work for files < 2MB or so)
def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(sample_submission)
